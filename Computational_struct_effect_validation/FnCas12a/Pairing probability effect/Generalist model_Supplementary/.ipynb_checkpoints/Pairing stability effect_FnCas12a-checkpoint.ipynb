# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_4_pairs_seed_paired_end_unpaired_015_035_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_4_pairs_seed_paired_end_unpaired_035_055_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_4_pairs_seed_paired_end_unpaired_055_075_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_4_pairs_seed_paired_end_unpaired_075_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '15%-35%': rate_a,
    '35%-55%': rate_b,
    '55%-75%': rate_c,
    '>75%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("FnCas12a 4-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.6912717223167419 0.6784811019897461 0.609138160943985 0.5880063772201538
# Group
# 15%-35%    63
# 35%-55%    66
# 55%-75%    64
# >75%       55
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_95521/1784897687.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_5_pairs_seed_paired_end_unpaired_015_035_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_seed_paired_end_unpaired_035_055_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_seed_paired_end_unpaired_055_075_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_seed_paired_end_unpaired_075_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '15%-35%': rate_a,
    '35%-55%': rate_b,
    '55%-75%': rate_c,
    '>75%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("FnCas12a 5-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.7114531397819519 0.699924886226654 0.6331342160701752 0.6302867531776428
# Group
# 15%-35%    55
# 35%-55%    57
# 55%-75%    54
# >75%       55
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_95521/3753687338.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_6_pairs_seed_paired_end_unpaired_015_035_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_seed_paired_end_unpaired_035_055_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_seed_paired_end_unpaired_055_075_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_seed_paired_end_unpaired_075_generalist_preds_FnCas12a.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '15%-35%': rate_a,
    '35%-55%': rate_b,
    '55%-75%': rate_c,
    '>75%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("FnCas12a 6-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.6979753971099854 0.6833165884017944 0.5921213626861572 0.5986242890357971
# Group
# 15%-35%    63
# 35%-55%    61
# 55%-75%    76
# >75%       57
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_95521/1832446512.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
