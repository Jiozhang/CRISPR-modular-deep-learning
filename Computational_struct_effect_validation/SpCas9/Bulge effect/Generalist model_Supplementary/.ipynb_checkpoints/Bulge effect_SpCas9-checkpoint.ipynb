# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []


with open('generated_random_dna_5_pairs_bulge_preds_HTCas9.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_no_bulge_preds_HTCas9.txt', 'r') as f:
    rate_b = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    'w/bulge': rate_a,
    'w/o bulge': rate_b
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(4, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("")          # removes the x-axis title
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("SpCas9 5-pairs", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.49560779333114624 0.44492799043655396
# Group
# w/bulge      38
# w/o bulge    80
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_69705/2720347225.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []


with open('generated_random_dna_6_pairs_bulge_preds_HTCas9.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_no_bulge_preds_HTCas9.txt', 'r') as f:
    rate_b = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    'w/bulge': rate_a,
    'w/o bulge': rate_b
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(4, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("")          # removes the x-axis title
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("SpCas9 6-pairs", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.4972480535507202 0.45590394735336304
# Group
# w/bulge      40
# w/o bulge    78
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_69705/2651769837.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []


with open('generated_random_dna_7_pairs_bulge_preds_HTCas9.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_7_pairs_no_bulge_preds_HTCas9.txt', 'r') as f:
    rate_b = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    'w/bulge': rate_a,
    'w/o bulge': rate_b
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(4, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("")          # removes the x-axis title
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("SpCas9 7-pairs", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.46642524003982544 0.41371122002601624
# Group
# w/bulge      41
# w/o bulge    80
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_69705/3046724160.py:58: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
