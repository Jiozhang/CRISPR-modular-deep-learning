# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_3_pairs_seed_complete_paired_end_complete_unpaired_025_045_preds_iMeta.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_3_pairs_seed_complete_paired_end_complete_unpaired_045_065_preds_iMeta.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_3_pairs_seed_complete_paired_end_complete_unpaired_065_085_preds_iMeta.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_3_pairs_seed_complete_paired_end_complete_unpaired_085_preds_iMeta.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '25%-45%': rate_a,
    '45%-65%': rate_b,
    '65%-85%': rate_c,
    '>85%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("LbCas12a 3-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.3593103885650635 0.3532191514968872 0.34594035148620605 0.33770620822906494
# Group
# 25%-45%    151
# 45%-65%    129
# 65%-85%    105
# >85%        26
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_82341/3767272492.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_4_pairs_seed_complete_paired_end_complete_unpaired_025_045_preds_iMeta.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_4_pairs_seed_complete_paired_end_complete_unpaired_045_065_preds_iMeta.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_4_pairs_seed_complete_paired_end_complete_unpaired_065_085_preds_iMeta.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_4_pairs_seed_complete_paired_end_complete_unpaired_085_preds_iMeta.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '25%-45%': rate_a,
    '45%-65%': rate_b,
    '65%-85%': rate_c,
    '>85%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)   
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("LbCas12a 4-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.347054660320282 0.34659814834594727 0.3419833183288574 0.32696792483329773
# Group
# 25%-45%    146
# 45%-65%    136
# 65%-85%    123
# >85%       120
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_82341/922161147.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_5_pairs_seed_complete_paired_end_complete_unpaired_025_045_preds_iMeta.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_seed_complete_paired_end_complete_unpaired_045_065_preds_iMeta.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_seed_complete_paired_end_complete_unpaired_065_085_preds_iMeta.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_5_pairs_seed_complete_paired_end_complete_unpaired_085_preds_iMeta.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '25%-45%': rate_a,
    '45%-65%': rate_b,
    '65%-85%': rate_c,
    '>85%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)  
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("LbCas12a 5-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.34317368268966675 0.3390064239501953 0.3349800109863281 0.3175269663333893
# Group
# 25%-45%    124
# 45%-65%    124
# 65%-85%    109
# >85%       122
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_82341/4097943353.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('generated_random_dna_6_pairs_seed_complete_paired_end_complete_unpaired_025_045_preds_iMeta.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_seed_complete_paired_end_complete_unpaired_045_065_preds_iMeta.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_seed_complete_paired_end_complete_unpaired_065_085_preds_iMeta.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('generated_random_dna_6_pairs_seed_complete_paired_end_complete_unpaired_085_preds_iMeta.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '25%-45%': rate_a,
    '45%-65%': rate_b,
    '65%-85%': rate_c,
    '>85%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)  
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("LbCas12a 6-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.3303735852241516 0.33877676725387573 0.32014334201812744 0.304744154214859
# Group
# 25%-45%    42
# 45%-65%    54
# 65%-85%    68
# >85%       82
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_82341/633681153.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
