# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('test_generated_random_dna_3_pairs_seed_paired_end_unpaired_020_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('test_generated_random_dna_3_pairs_seed_paired_end_unpaired_020_040_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('test_generated_random_dna_3_pairs_seed_paired_end_unpaired_040_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('test_generated_random_dna_3_pairs_seed_paired_end_unpaired_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '<20%': rate_a,
    '20%-40%': rate_b,
    '40%-60%': rate_c,
    '>60%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("RfxCas13d 3-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.8032484948635101 0.829084038734436 0.7826308608055115 0.7788370847702026
# Group
# 20%-40%    54
# 40%-60%    54
# <20%       58
# >60%       37
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_83581/1431205511.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('test_generated_random_dna_4_pairs_seed_paired_end_unpaired_020_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('test_generated_random_dna_4_pairs_seed_paired_end_unpaired_020_040_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('test_generated_random_dna_4_pairs_seed_paired_end_unpaired_040_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('test_generated_random_dna_4_pairs_seed_paired_end_unpaired_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '<20%': rate_a,
    '20%-40%': rate_b,
    '40%-60%': rate_c,
    '>60%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("RfxCas13d 4-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.8137795925140381 0.7867948114871979 0.7748105525970459 0.7798395156860352
# Group
# 20%-40%    64
# 40%-60%    61
# <20%       67
# >60%       53
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_83581/265189157.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('test_generated_random_dna_5_pairs_seed_paired_end_unpaired_020_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('test_generated_random_dna_5_pairs_seed_paired_end_unpaired_020_040_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('test_generated_random_dna_5_pairs_seed_paired_end_unpaired_040_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('test_generated_random_dna_5_pairs_seed_paired_end_unpaired_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '<20%': rate_a,
    '20%-40%': rate_b,
    '40%-60%': rate_c,
    '>60%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("RfxCas13d 5-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.7746622562408447 0.7932523190975189 0.7943934202194214 0.721082329750061
# Group
# 20%-40%    60
# 40%-60%    65
# <20%       53
# >60%       63
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_83581/945337457.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(

# %%
import RNA
from nupack import *
import random
import math

rate_a = []
rate_b = []
rate_c = []
rate_d = []


with open('test_generated_random_dna_6_pairs_seed_paired_end_unpaired_020_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_a = [line.strip() for line in f]

with open('test_generated_random_dna_6_pairs_seed_paired_end_unpaired_020_040_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_b = [line.strip() for line in f]

with open('test_generated_random_dna_6_pairs_seed_paired_end_unpaired_040_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_c = [line.strip() for line in f]

with open('test_generated_random_dna_6_pairs_seed_paired_end_unpaired_060_preds_RfxCas13d_mmc5_validation.txt', 'r') as f:
    rate_d = [line.strip() for line in f]


import statistics

median_a = statistics.median(map(float, rate_a))
median_b = statistics.median(map(float, rate_b))
median_c = statistics.median(map(float, rate_c))
median_d = statistics.median(map(float, rate_d))


'''
average_p = sum(map(float, rate_p)) / len(rate_p)
average_n = sum(map(float, rate_n)) / len(rate_n)
'''

print(median_a, median_b, median_c, median_d)


import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statistics

# Organize the rate lists into a dictionary
score_bin_data = {
    '<20%': rate_a,
    '20%-40%': rate_b,
    '40%-60%': rate_c,
    '>60%': rate_d,
}

# Convert to DataFrame
plot_data = []
for label, rates in score_bin_data.items():
    for r in rates:
        try:
            plot_data.append({'Group': label, 'Predicted Indel Frequency (%)': float(r)})
        except:
            continue  # skip invalid data points

df = pd.DataFrame(plot_data)
counts = df.groupby("Group")["Predicted Indel Frequency (%)"].count()
print(counts)

# Plot
plt.figure(figsize=(7, 6), dpi=600)

sns.boxplot(
    data=df,
    x='Group',
    y='Predicted Indel Frequency (%)',
    palette='coolwarm_r',
    # Box outline
    linewidth=2.5,
    boxprops=dict(edgecolor='black'),
    # Whiskers (vertical)
    whiskerprops=dict(color='black', linewidth=2.5),
    # Caps (horizontal)
    capprops=dict(color='black', linewidth=2.5),
    # Median line
    medianprops=dict(color='black', linewidth=3),
    # Outliers (optional)
    flierprops=dict(
        marker='o',
        markersize=6,
        markerfacecolor='none',   # <-- hollow
        markeredgecolor='black',
        linewidth=1.5,
        alpha=0.8
    )
)

from matplotlib.ticker import MaxNLocator

ax = plt.gca()
ax.yaxis.set_major_locator(MaxNLocator(nbins=5))

plt.ylabel("Predicted Activity", fontsize=24)
plt.xlabel("MFE frequency", fontsize=24)         
plt.xticks(fontsize=18)
plt.yticks(fontsize=24)
plt.title("RfxCas13d 6-pair", fontsize=24)

plt.tight_layout()
plt.show()
# Out:
# 0.7627572417259216 0.7107013463973999 0.7169835269451141 0.6794601678848267
# Group
# 20%-40%    63
# 40%-60%    62
# <20%       55
# >60%       80
# Name: Predicted Indel Frequency (%), dtype: int64
# /var/folders/8p/2p_212ld2qvgjsycxk_lmmg00000gn/T/ipykernel_83581/61000862.py:70: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(
