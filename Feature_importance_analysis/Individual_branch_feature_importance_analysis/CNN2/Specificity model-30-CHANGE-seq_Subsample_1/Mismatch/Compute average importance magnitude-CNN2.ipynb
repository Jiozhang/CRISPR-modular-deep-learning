# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the importance-magnitude CSV files
input_folder = Path(".")

# Match files such as:
filename_pattern = re.compile(
    r"^indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_(\d+)\.csv$"
)

# Detect matching files
matching_files = []

for file_path in input_folder.glob(
    "indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_*.csv"
):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

# Sort by model number
matching_files.sort(key=lambda x: x[0])

print(f"Detected {len(matching_files)} importance-magnitude files:")

for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")

if len(matching_files) == 0:
    raise FileNotFoundError(
        "No matching importance-magnitude CSV files were found."
    )

if len(matching_files) != 10:
    print(
        f"\nWarning: Expected 10 files, but detected "
        f"{len(matching_files)} files."
    )


# Read and combine all files
all_importance_tables = []

for model_number, file_path in matching_files:

    df = pd.read_csv(file_path)

    # Check that the expected columns exist
    required_columns = {"Feature", "Importance Magnitude"}

    if not required_columns.issubset(df.columns):
        raise ValueError(
            f"{file_path.name} does not contain the required columns: "
            f"'Feature' and 'Importance Magnitude'."
        )

    # Keep only the required columns
    df = df[["Feature", "Importance Magnitude"]].copy()

    # Convert importance values to numeric
    df["Importance Magnitude"] = pd.to_numeric(
        df["Importance Magnitude"],
        errors="coerce"
    )

    # Add model number for tracking
    df["Model Number"] = model_number

    all_importance_tables.append(df)

# Combine all model tables
combined_df = pd.concat(
    all_importance_tables,
    ignore_index=True
)

# Calculate average importance magnitude for each feature
average_importance = (
    combined_df
    .groupby("Feature", as_index=False)
    .agg(
        Average_Importance_Magnitude=(
            "Importance Magnitude",
            "mean"
        ),
        Number_of_Models=(
            "Importance Magnitude",
            "count"
        )
    )
)

# Sort from highest to lowest average importance
average_importance = average_importance.sort_values(
    by="Average_Importance_Magnitude",
    ascending=False,
    ignore_index=True
)

# Save the final table
output_file = (
    input_folder /
    "indiv_average_importance_magnitude_Specificity_model_mismatch_CNN2.csv"
)

average_importance.to_csv(output_file, index=False)

print(f"\nSaved: {output_file.name}")
print("\nAverage importance magnitude table:")
print(average_importance)
# Out:
# Detected 10 importance-magnitude files:
# Model 12: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_12.csv
# Model 13: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_13.csv
# Model 16: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_16.csv
# Model 45: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_45.csv
# Model 52: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_52.csv
# Model 80: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_80.csv
# Model 81: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_81.csv
# Model 82: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_82.csv
# Model 87: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_87.csv
# Model 97: indiv_importance_magnitude_Specificity_model_mismatch_CNN2_trial_97.csv
#
# Saved: indiv_average_importance_magnitude_Specificity_model_mismatch_CNN2.csv
#
# Average importance magnitude table:
#                  Feature  Average_Importance_Magnitude  Number_of_Models
# 0    Pos5_Paired-Opening                      0.007723                10
# 1    Pos4_Paired-Opening                      0.007606                10
# 2          Pos5_Unpaired                      0.007400                10
# 3          Pos4_Unpaired                      0.007001                10
# 4   Pos15_Paired-Opening                      0.006922                10
# 5         Pos20_Unpaired                      0.006835                10
# 6         Pos15_Unpaired                      0.006011                10
# 7    Pos9_Paired-Opening                      0.005907                10
# 8          Pos9_Unpaired                      0.005494                10
# 9   Pos17_Paired-Opening                      0.005369                10
# 10   Pos6_Paired-Opening                      0.005257                10
# 11   Pos8_Paired-Opening                      0.005254                10
# 12         Pos8_Unpaired                      0.005070                10
# 13  Pos14_Paired-Opening                      0.004984                10
# 14        Pos17_Unpaired                      0.004921                10
# 15   Pos7_Paired-Opening                      0.004729                10
# 16  Pos18_Paired-Opening                      0.004626                10
# 17        Pos14_Unpaired                      0.004539                10
# 18         Pos6_Unpaired                      0.004390                10
# 19        Pos19_Unpaired                      0.004142                10
# 20        Pos18_Unpaired                      0.004125                10
# 21         Pos1_Unpaired                      0.003771                10
# 22  Pos19_Paired-Opening                      0.003749                10
# 23         Pos7_Unpaired                      0.003713                10
# 24  Pos16_Paired-Opening                      0.003646                10
# 25         Pos3_Unpaired                      0.003533                10
# 26        Pos16_Unpaired                      0.003222                10
# 27  Pos20_Paired-Opening                      0.003192                10
# 28  Pos10_Paired-Opening                      0.003075                10
# 29   Pos2_Paired-Opening                      0.003061                10
# 30   Pos3_Paired-Opening                      0.003040                10
# 31         Pos2_Unpaired                      0.002989                10
# 32        Pos10_Unpaired                      0.002829                10
# 33  Pos12_Paired-Opening                      0.002639                10
# 34   Pos1_Paired-Opening                      0.002605                10
# 35  Pos11_Paired-Opening                      0.002562                10
# 36  Pos13_Paired-Opening                      0.002496                10
# 37        Pos12_Unpaired                      0.002396                10
# 38        Pos11_Unpaired                      0.002233                10
# 39        Pos13_Unpaired                      0.002161                10
# 40  Pos20_Paired-Closing                      0.000039                10
# 41  Pos19_Paired-Closing                      0.000031                10
# 42  Pos17_Paired-Closing                      0.000030                10
# 43  Pos18_Paired-Closing                      0.000023                10
# 44  Pos16_Paired-Closing                      0.000021                10
# 45  Pos14_Paired-Closing                      0.000010                10
# 46  Pos13_Paired-Closing                      0.000009                10
# 47  Pos15_Paired-Closing                      0.000007                10
# 48  Pos12_Paired-Closing                      0.000007                10
# 49  Pos10_Paired-Closing                      0.000006                10
# 50  Pos11_Paired-Closing                      0.000005                10
# 51   Pos9_Paired-Closing                      0.000004                10
# 52   Pos6_Paired-Closing                      0.000000                10
# 53   Pos7_Paired-Closing                      0.000000                10
# 54   Pos5_Paired-Closing                      0.000000                10
# 55   Pos4_Paired-Closing                      0.000000                10
# 56   Pos8_Paired-Closing                      0.000000                10
# 57   Pos3_Paired-Closing                      0.000000                10
# 58   Pos2_Paired-Closing                      0.000000                10
# 59   Pos1_Paired-Closing                      0.000000                10

# %%
# PAM-order adjustment (reverse the order of the first 20 bases)
import pandas as pd
import re

# Input and output files
input_file = "indiv_average_importance_magnitude_Specificity_model_mismatch_CNN2.csv"
output_file = "indiv_PAM_adjusted_average_importance_magnitude_Specificity_model_mismatch_CNN2.csv"

# Read the CSV file
df = pd.read_csv(input_file)

# Function to adjust positions 1–20 only
def adjust_feature_position(feature):
    feature = str(feature).strip()

    # Match feature names such as Pos20_G
    match = re.match(r"^Pos(\d+)_(.+)$", feature)

    if not match:
        # Preserve feature names that do not follow the expected format
        return feature

    position = int(match.group(1))
    feature_type = match.group(2)

    # Reverse numbering only for the first 20 positions
    if 1 <= position <= 20:
        adjusted_position = 21 - position
        return f"Pos{adjusted_position}_{feature_type}"

    # Keep positions greater than 20 unchanged
    return feature


# Apply conversion to the Feature column
df["Feature"] = df["Feature"].apply(adjust_feature_position)

# Save the adjusted CSV file
df.to_csv(output_file, index=False)

print(f"Saved: {output_file}")
# Out:
# Saved: indiv_PAM_adjusted_average_importance_magnitude_Specificity_model_mismatch_CNN2.csv

# %%
import pandas as pd

# Read the average importance-magnitude CSV file
df = pd.read_csv("indiv_PAM_adjusted_average_importance_magnitude_Specificity_model_mismatch_CNN2.csv")

# Extract position and Struct from feature names
extracted = df["Feature"].str.extract(
    r"^Pos(\d+)_(Unpaired|Paired-Opening|Paired-Closing)$"
)

df["Position"] = pd.to_numeric(extracted[0], errors="coerce")
df["Struct"] = extracted[1]

# Ensure importance magnitudes are numeric
df["Average_Importance_Magnitude"] = pd.to_numeric(
    df["Average_Importance_Magnitude"],
    errors="coerce"
)

# Remove rows that don't match the expected format
df = df.dropna(
    subset=["Position", "Struct", "Average_Importance_Magnitude"]
).copy()

df["Position"] = df["Position"].astype(int)

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

Structs = ["Unpaired", "Paired-Opening", "Paired-Closing"]

results = []

for Struct in Structs:
    Struct_df = df[df["Struct"] == Struct]

    row = {"Struct": Struct}

    for window_name, (start, end) in windows.items():
        avg = Struct_df.loc[
            Struct_df["Position"].between(start, end),
            "Average_Importance_Magnitude"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

# Save as CSV
result_df.to_csv(
    "indiv_PAM_adjusted_average_importance_magnitude_by_Struct_position_range_Specificity_model_mismatch_CNN2.csv",
    index=False
)

print(result_df)
# Out:
#            Struct   First_6  Middle_8    Last_6
# 0        Unpaired  0.004876  0.003554  0.004847
# 1  Paired-Opening  0.004584  0.003956  0.004882
# 2  Paired-Closing  0.000025  0.000005  0.000000
