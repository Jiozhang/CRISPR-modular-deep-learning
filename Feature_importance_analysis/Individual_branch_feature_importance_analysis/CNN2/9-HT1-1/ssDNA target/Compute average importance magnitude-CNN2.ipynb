# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the importance-magnitude CSV files
input_folder = Path(".")

# Match files such as:
filename_pattern = re.compile(
    r"^indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_(\d+)\.csv$"
)

# Detect matching files
matching_files = []

for file_path in input_folder.glob(
    "indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_*.csv"
):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

# Sort by model number
matching_files.sort(key=lambda x: x[0])

print(f"Detected {len(matching_files)} importance-magnitude files:")

for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")

if len(matching_files) == 0:
    raise FileNotFoundError(
        "No matching importance-magnitude CSV files were found."
    )

if len(matching_files) != 10:
    print(
        f"\nWarning: Expected 10 files, but detected "
        f"{len(matching_files)} files."
    )


# Read and combine all files
all_importance_tables = []

for model_number, file_path in matching_files:

    df = pd.read_csv(file_path)

    # Check that the expected columns exist
    required_columns = {"Feature", "Importance Magnitude"}

    if not required_columns.issubset(df.columns):
        raise ValueError(
            f"{file_path.name} does not contain the required columns: "
            f"'Feature' and 'Importance Magnitude'."
        )

    # Keep only the required columns
    df = df[["Feature", "Importance Magnitude"]].copy()

    # Convert importance values to numeric
    df["Importance Magnitude"] = pd.to_numeric(
        df["Importance Magnitude"],
        errors="coerce"
    )

    # Add model number for tracking
    df["Model Number"] = model_number

    all_importance_tables.append(df)

# Combine all model tables
combined_df = pd.concat(
    all_importance_tables,
    ignore_index=True
)

# Calculate average importance magnitude for each feature
average_importance = (
    combined_df
    .groupby("Feature", as_index=False)
    .agg(
        Average_Importance_Magnitude=(
            "Importance Magnitude",
            "mean"
        ),
        Number_of_Models=(
            "Importance Magnitude",
            "count"
        )
    )
)

# Sort from highest to lowest average importance
average_importance = average_importance.sort_values(
    by="Average_Importance_Magnitude",
    ascending=False,
    ignore_index=True
)

# Save the final table
output_file = (
    input_folder /
    "indiv_average_importance_magnitude_cnn2_HT11_ssDNA_target_ah.csv"
)

average_importance.to_csv(output_file, index=False)

print(f"\nSaved: {output_file.name}")
print("\nAverage importance magnitude table:")
print(average_importance)
# Out:
# Detected 10 importance-magnitude files:
# Model 18: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_18.csv
# Model 19: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_19.csv
# Model 24: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_24.csv
# Model 32: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_32.csv
# Model 40: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_40.csv
# Model 54: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_54.csv
# Model 62: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_62.csv
# Model 65: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_65.csv
# Model 81: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_81.csv
# Model 82: indiv_importance_magnitude_cnn2_HT11_ssDNA_target_ah_82.csv
#
# Saved: indiv_average_importance_magnitude_cnn2_HT11_ssDNA_target_ah.csv
#
# Average importance magnitude table:
#                  Feature  Average_Importance_Magnitude  Number_of_Models
# 0          Pos4_Unpaired                      0.002534                10
# 1          Pos3_Unpaired                      0.001658                10
# 2          Pos1_Unpaired                      0.001548                10
# 3    Pos4_Paired-Opening                      0.001475                10
# 4         Pos17_Unpaired                      0.001389                10
# 5          Pos2_Unpaired                      0.001319                10
# 6         Pos16_Unpaired                      0.001226                10
# 7         Pos15_Unpaired                      0.001221                10
# 8   Pos17_Paired-Closing                      0.001124                10
# 9    Pos1_Paired-Opening                      0.000952                10
# 10  Pos16_Paired-Closing                      0.000919                10
# 11        Pos14_Unpaired                      0.000898                10
# 12        Pos18_Unpaired                      0.000897                10
# 13        Pos13_Unpaired                      0.000890                10
# 14  Pos15_Paired-Closing                      0.000867                10
# 15         Pos5_Unpaired                      0.000859                10
# 16        Pos19_Unpaired                      0.000803                10
# 17        Pos12_Unpaired                      0.000798                10
# 18   Pos2_Paired-Opening                      0.000746                10
# 19   Pos5_Paired-Opening                      0.000733                10
# 20   Pos3_Paired-Opening                      0.000710                10
# 21        Pos20_Unpaired                      0.000680                10
# 22         Pos6_Unpaired                      0.000676                10
# 23  Pos19_Paired-Closing                      0.000669                10
# 24         Pos9_Unpaired                      0.000648                10
# 25   Pos6_Paired-Opening                      0.000634                10
# 26         Pos8_Unpaired                      0.000628                10
# 27  Pos18_Paired-Closing                      0.000598                10
# 28        Pos10_Unpaired                      0.000570                10
# 29   Pos7_Paired-Opening                      0.000569                10
# 30        Pos11_Unpaired                      0.000565                10
# 31         Pos7_Unpaired                      0.000558                10
# 32  Pos20_Paired-Closing                      0.000529                10
# 33   Pos8_Paired-Opening                      0.000514                10
# 34  Pos12_Paired-Closing                      0.000504                10
# 35  Pos14_Paired-Closing                      0.000502                10
# 36   Pos9_Paired-Opening                      0.000449                10
# 37  Pos13_Paired-Closing                      0.000435                10
# 38  Pos11_Paired-Closing                      0.000328                10
# 39  Pos10_Paired-Opening                      0.000293                10
# 40  Pos10_Paired-Closing                      0.000245                10
# 41  Pos11_Paired-Opening                      0.000236                10
# 42   Pos9_Paired-Closing                      0.000225                10
# 43  Pos12_Paired-Opening                      0.000138                10
# 44   Pos8_Paired-Closing                      0.000111                10
# 45  Pos13_Paired-Opening                      0.000067                10
# 46  Pos14_Paired-Opening                      0.000012                10
# 47   Pos7_Paired-Closing                      0.000007                10
# 48   Pos3_Paired-Closing                      0.000000                10
# 49  Pos15_Paired-Opening                      0.000000                10
# 50  Pos16_Paired-Opening                      0.000000                10
# 51   Pos4_Paired-Closing                      0.000000                10
# 52  Pos17_Paired-Opening                      0.000000                10
# 53   Pos6_Paired-Closing                      0.000000                10
# 54  Pos18_Paired-Opening                      0.000000                10
# 55  Pos19_Paired-Opening                      0.000000                10
# 56   Pos5_Paired-Closing                      0.000000                10
# 57  Pos20_Paired-Opening                      0.000000                10
# 58   Pos2_Paired-Closing                      0.000000                10
# 59   Pos1_Paired-Closing                      0.000000                10

# %%
import pandas as pd

# Read the average importance-magnitude CSV file
df = pd.read_csv("indiv_average_importance_magnitude_cnn2_HT11_ssDNA_target_ah.csv")

# Extract position and Struct from feature names
extracted = df["Feature"].str.extract(
    r"^Pos(\d+)_(Unpaired|Paired-Opening|Paired-Closing)$"
)

df["Position"] = pd.to_numeric(extracted[0], errors="coerce")
df["Struct"] = extracted[1]

# Ensure importance magnitudes are numeric
df["Average_Importance_Magnitude"] = pd.to_numeric(
    df["Average_Importance_Magnitude"],
    errors="coerce"
)

# Remove rows that don't match the expected format
df = df.dropna(
    subset=["Position", "Struct", "Average_Importance_Magnitude"]
).copy()

df["Position"] = df["Position"].astype(int)

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

Structs = ["Unpaired", "Paired-Opening", "Paired-Closing"]

results = []

for Struct in Structs:
    Struct_df = df[df["Struct"] == Struct]

    row = {"Struct": Struct}

    for window_name, (start, end) in windows.items():
        avg = Struct_df.loc[
            Struct_df["Position"].between(start, end),
            "Average_Importance_Magnitude"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

# Save as CSV
result_df.to_csv(
    "indiv_average_importance_magnitude_by_Struct_position_range_cnn2_HT11_ssDNA_target_ah.csv",
    index=False
)

print(result_df)
# Out:
#            Struct   First_6  Middle_8    Last_6
# 0        Unpaired  0.001433  0.000694  0.001036
# 1  Paired-Opening  0.000875  0.000285  0.000000
# 2  Paired-Closing  0.000000  0.000295  0.000784
