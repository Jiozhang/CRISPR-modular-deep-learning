# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the importance-magnitude CSV files
input_folder = Path(".")

# Match files such as:
filename_pattern = re.compile(
    r"^indiv_importance_magnitude_Specificity_model_MLP_trial_(\d+)\.csv$"
)

# Detect matching files
matching_files = []

for file_path in input_folder.glob(
    "indiv_importance_magnitude_Specificity_model_MLP_trial_*.csv"
):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

# Sort by model number
matching_files.sort(key=lambda x: x[0])

print(f"Detected {len(matching_files)} importance-magnitude files:")

for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")

if len(matching_files) == 0:
    raise FileNotFoundError(
        "No matching importance-magnitude CSV files were found."
    )

if len(matching_files) != 10:
    print(
        f"\nWarning: Expected 10 files, but detected "
        f"{len(matching_files)} files."
    )


# Read and combine all files
all_importance_tables = []

for model_number, file_path in matching_files:

    df = pd.read_csv(file_path)

    # Check that the expected columns exist
    required_columns = {"Feature", "Importance Magnitude"}

    if not required_columns.issubset(df.columns):
        raise ValueError(
            f"{file_path.name} does not contain the required columns: "
            f"'Feature' and 'Importance Magnitude'."
        )

    # Keep only the required columns
    df = df[["Feature", "Importance Magnitude"]].copy()

    # Convert importance values to numeric
    df["Importance Magnitude"] = pd.to_numeric(
        df["Importance Magnitude"],
        errors="coerce"
    )

    # Add model number for tracking
    df["Model Number"] = model_number

    all_importance_tables.append(df)

# Combine all model tables
combined_df = pd.concat(
    all_importance_tables,
    ignore_index=True
)

# Calculate average importance magnitude for each feature
average_importance = (
    combined_df
    .groupby("Feature", as_index=False)
    .agg(
        Average_Importance_Magnitude=(
            "Importance Magnitude",
            "mean"
        ),
        Number_of_Models=(
            "Importance Magnitude",
            "count"
        )
    )
)

# Sort from highest to lowest average importance
average_importance = average_importance.sort_values(
    by="Average_Importance_Magnitude",
    ascending=False,
    ignore_index=True
)

# Save the final table
output_file = (
    input_folder /
    "indiv_average_importance_magnitude_Specificity_model_MLP.csv"
)

average_importance.to_csv(output_file, index=False)

print(f"\nSaved: {output_file.name}")
print("\nAverage importance magnitude table:")
print(average_importance)
# Out:
# Detected 10 importance-magnitude files:
# Model 44: indiv_importance_magnitude_Specificity_model_MLP_trial_44.csv
# Model 46: indiv_importance_magnitude_Specificity_model_MLP_trial_46.csv
# Model 58: indiv_importance_magnitude_Specificity_model_MLP_trial_58.csv
# Model 60: indiv_importance_magnitude_Specificity_model_MLP_trial_60.csv
# Model 61: indiv_importance_magnitude_Specificity_model_MLP_trial_61.csv
# Model 67: indiv_importance_magnitude_Specificity_model_MLP_trial_67.csv
# Model 90: indiv_importance_magnitude_Specificity_model_MLP_trial_90.csv
# Model 91: indiv_importance_magnitude_Specificity_model_MLP_trial_91.csv
# Model 94: indiv_importance_magnitude_Specificity_model_MLP_trial_94.csv
# Model 97: indiv_importance_magnitude_Specificity_model_MLP_trial_97.csv
#
# Saved: indiv_average_importance_magnitude_Specificity_model_MLP.csv
#
# Average importance magnitude table:
#                                   Feature  Average_Importance_Magnitude  \
# 0                            dsDNA target                      0.092651
# 1   bh_maximal consecutive unpaired bases                      0.040295
# 2                          bh_3' overhang                      0.030368
# 3                          central region                      0.023844
# 4                          bh_5' overhang                      0.023722
# 5                       PAM-distal region                      0.022714
# 6     ah_maximal consecutive paired bases                      0.022231
# 7                            crRNA spacer                      0.022051
# 8                              ah_3' stem                      0.021531
# 9   ah_maximal consecutive unpaired bases                      0.018556
# 10                    PAM-proximal region                      0.017870
# 11    bh_maximal consecutive paired bases                      0.016694
# 12                             bh_3' stem                      0.014777
# 13                             bh_5' stem                      0.012624
# 14                         ah_5' overhang                      0.010679
# 15                         ah_3' overhang                      0.008721
# 16                             ah_5' stem                      0.007537
#
#     Number_of_Models
# 0                 10
# 1                 10
# 2                 10
# 3                 10
# 4                 10
# 5                 10
# 6                 10
# 7                 10
# 8                 10
# 9                 10
# 10                10
# 11                10
# 12                10
# 13                10
# 14                10
# 15                10
# 16                10

# %%
import pandas as pd

# Input and output files
input_file = "indiv_average_importance_magnitude_Specificity_model_MLP.csv"
output_file = "reordered_indiv_average_importance_magnitude_Specificity_model_MLP.csv"

# Desired feature order
desired_order = [
    "crRNA spacer",
    "bh_maximal consecutive paired bases",
    "bh_maximal consecutive unpaired bases",
    "bh_5' overhang",
    "bh_3' overhang",
    "bh_5' stem",
    "bh_3' stem",
    "dsDNA target",
    "ah_maximal consecutive paired bases",
    "ah_maximal consecutive unpaired bases",
    "ah_5' overhang",
    "ah_3' overhang",
    "ah_5' stem",
    "ah_3' stem",
    "PAM-proximal region",
    "central region",
    "PAM-distal region"
]

# Read the CSV
df = pd.read_csv(input_file)

# Make the Feature column a categorical with the desired order
df["Feature"] = pd.Categorical(
    df["Feature"],
    categories=desired_order,
    ordered=True
)

# Sort according to the specified order
df = df.sort_values("Feature").reset_index(drop=True)

# Save the reordered CSV
df.to_csv(output_file, index=False)

print(f"Reordered file saved as '{output_file}'.")
# Out:
# Reordered file saved as 'reordered_indiv_average_importance_magnitude_Specificity_model_MLP.csv'.
