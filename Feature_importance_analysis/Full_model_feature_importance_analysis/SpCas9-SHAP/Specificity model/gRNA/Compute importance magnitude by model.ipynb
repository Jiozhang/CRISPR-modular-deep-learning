# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the SHAP CSV files
input_folder = Path(".")

# File-name pattern:
filename_pattern = re.compile(
    r"^shap_values_cnn1_Specificity_model_trial_(\d+)\.csv$"
)

# Find and sort all matching files by model number
matching_files = []

for file_path in input_folder.glob("shap_values_cnn1_Specificity_model_trial_*.csv"):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

matching_files.sort(key=lambda item: item[0])

print(f"Detected {len(matching_files)} matching files:")
for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")


# Process every detected CSV file
for model_number, input_path in matching_files:

    print(f"\nProcessing model {model_number}: {input_path.name}")

    # Pandas normally renames the second duplicate column:
    df = pd.read_csv(input_path)

    # Select the second occurrence of duplicated columns
    shap_df = df.loc[:, df.columns.str.endswith(".1")].copy()

    if shap_df.shape[1] == 0:
        print(
            f"Warning: No columns ending in '.1' were detected in "
            f"{input_path.name}. Skipping this file."
        )
        continue

    # Restore the original feature names
    shap_df.columns = shap_df.columns.str.replace(
        r"\.1$",
        "",
        regex=True
    )

    # Make sure values are numeric
    # Invalid entries are converted to NaN and ignored by mean()
    shap_df = shap_df.apply(pd.to_numeric, errors="coerce")

    # Importance magnitude = mean absolute SHAP value across all samples
    importance_magnitude = shap_df.abs().mean(axis=0)

    # Create output table
    importance_table = pd.DataFrame({
        "Feature": importance_magnitude.index,
        "Importance Magnitude": importance_magnitude.values
    })

    # Sort from highest to lowest importance
    importance_table = importance_table.sort_values(
        by="Importance Magnitude",
        ascending=False,
        ignore_index=True
    )

    # Output file name
    output_path = input_folder / (
        f"importance_magnitude_cnn1_Specificity_model_trial_{model_number}.csv"
    )

    importance_table.to_csv(output_path, index=False)

    print(f"Saved: {output_path.name}")

print("\nAll matching files have been processed.")
# Out:
# Detected 10 matching files:
# Model 38: shap_values_cnn1_Specificity_model_trial_38.csv
# Model 46: shap_values_cnn1_Specificity_model_trial_46.csv
# Model 47: shap_values_cnn1_Specificity_model_trial_47.csv
# Model 52: shap_values_cnn1_Specificity_model_trial_52.csv
# Model 54: shap_values_cnn1_Specificity_model_trial_54.csv
# Model 57: shap_values_cnn1_Specificity_model_trial_57.csv
# Model 59: shap_values_cnn1_Specificity_model_trial_59.csv
# Model 75: shap_values_cnn1_Specificity_model_trial_75.csv
# Model 77: shap_values_cnn1_Specificity_model_trial_77.csv
# Model 95: shap_values_cnn1_Specificity_model_trial_95.csv
#
# Processing model 38: shap_values_cnn1_Specificity_model_trial_38.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_38.csv
#
# Processing model 46: shap_values_cnn1_Specificity_model_trial_46.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_46.csv
#
# Processing model 47: shap_values_cnn1_Specificity_model_trial_47.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_47.csv
#
# Processing model 52: shap_values_cnn1_Specificity_model_trial_52.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_52.csv
#
# Processing model 54: shap_values_cnn1_Specificity_model_trial_54.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_54.csv
#
# Processing model 57: shap_values_cnn1_Specificity_model_trial_57.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_57.csv
#
# Processing model 59: shap_values_cnn1_Specificity_model_trial_59.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_59.csv
#
# Processing model 75: shap_values_cnn1_Specificity_model_trial_75.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_75.csv
#
# Processing model 77: shap_values_cnn1_Specificity_model_trial_77.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_77.csv
#
# Processing model 95: shap_values_cnn1_Specificity_model_trial_95.csv
# Saved: importance_magnitude_cnn1_Specificity_model_trial_95.csv
#
# All matching files have been processed.

# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the SHAP CSV files
input_folder = Path(".")

# File-name pattern:
filename_pattern = re.compile(
    r"^shap_values_cnn2_Specificity_model_trial_(\d+)\.csv$"
)

# Find and sort all matching files by model number
matching_files = []

for file_path in input_folder.glob("shap_values_cnn2_Specificity_model_trial_*.csv"):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

matching_files.sort(key=lambda item: item[0])

print(f"Detected {len(matching_files)} matching files:")
for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")


# Process every detected CSV file
for model_number, input_path in matching_files:

    print(f"\nProcessing model {model_number}: {input_path.name}")

    # Pandas normally renames the second duplicate column:
    df = pd.read_csv(input_path)

    # Select the second occurrence of duplicated columns
    shap_df = df.loc[:, df.columns.str.endswith(".1")].copy()

    if shap_df.shape[1] == 0:
        print(
            f"Warning: No columns ending in '.1' were detected in "
            f"{input_path.name}. Skipping this file."
        )
        continue

    # Restore the original feature names
    shap_df.columns = shap_df.columns.str.replace(
        r"\.1$",
        "",
        regex=True
    )

    # Make sure values are numeric
    # Invalid entries are converted to NaN and ignored by mean()
    shap_df = shap_df.apply(pd.to_numeric, errors="coerce")

    # Importance magnitude = mean absolute SHAP value across all samples
    importance_magnitude = shap_df.abs().mean(axis=0)

    # Create output table
    importance_table = pd.DataFrame({
        "Feature": importance_magnitude.index,
        "Importance Magnitude": importance_magnitude.values
    })

    # Sort from highest to lowest importance
    importance_table = importance_table.sort_values(
        by="Importance Magnitude",
        ascending=False,
        ignore_index=True
    )

    # Output file name
    output_path = input_folder / (
        f"importance_magnitude_cnn2_Specificity_model_trial_{model_number}.csv"
    )

    importance_table.to_csv(output_path, index=False)

    print(f"Saved: {output_path.name}")

print("\nAll matching files have been processed.")
# Out:
# Detected 10 matching files:
# Model 38: shap_values_cnn2_Specificity_model_trial_38.csv
# Model 46: shap_values_cnn2_Specificity_model_trial_46.csv
# Model 47: shap_values_cnn2_Specificity_model_trial_47.csv
# Model 52: shap_values_cnn2_Specificity_model_trial_52.csv
# Model 54: shap_values_cnn2_Specificity_model_trial_54.csv
# Model 57: shap_values_cnn2_Specificity_model_trial_57.csv
# Model 59: shap_values_cnn2_Specificity_model_trial_59.csv
# Model 75: shap_values_cnn2_Specificity_model_trial_75.csv
# Model 77: shap_values_cnn2_Specificity_model_trial_77.csv
# Model 95: shap_values_cnn2_Specificity_model_trial_95.csv
#
# Processing model 38: shap_values_cnn2_Specificity_model_trial_38.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_38.csv
#
# Processing model 46: shap_values_cnn2_Specificity_model_trial_46.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_46.csv
#
# Processing model 47: shap_values_cnn2_Specificity_model_trial_47.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_47.csv
#
# Processing model 52: shap_values_cnn2_Specificity_model_trial_52.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_52.csv
#
# Processing model 54: shap_values_cnn2_Specificity_model_trial_54.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_54.csv
#
# Processing model 57: shap_values_cnn2_Specificity_model_trial_57.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_57.csv
#
# Processing model 59: shap_values_cnn2_Specificity_model_trial_59.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_59.csv
#
# Processing model 75: shap_values_cnn2_Specificity_model_trial_75.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_75.csv
#
# Processing model 77: shap_values_cnn2_Specificity_model_trial_77.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_77.csv
#
# Processing model 95: shap_values_cnn2_Specificity_model_trial_95.csv
# Saved: importance_magnitude_cnn2_Specificity_model_trial_95.csv
#
# All matching files have been processed.

# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the SHAP CSV files
input_folder = Path(".")

# File-name pattern:
filename_pattern = re.compile(
    r"^shap_values_mlp_Specificity_model_trial_(\d+)\.csv$"
)

# Find and sort all matching files by model number
matching_files = []

for file_path in input_folder.glob("shap_values_mlp_Specificity_model_trial_*.csv"):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

matching_files.sort(key=lambda item: item[0])

print(f"Detected {len(matching_files)} matching files:")
for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")


# Process every detected CSV file
for model_number, input_path in matching_files:

    print(f"\nProcessing model {model_number}: {input_path.name}")

    # Pandas normally renames the second duplicate column:
    df = pd.read_csv(input_path)

    # Select the second occurrence of duplicated columns
    shap_df = df.loc[:, df.columns.str.endswith(".1")].copy()

    if shap_df.shape[1] == 0:
        print(
            f"Warning: No columns ending in '.1' were detected in "
            f"{input_path.name}. Skipping this file."
        )
        continue

    # Restore the original feature names
    shap_df.columns = shap_df.columns.str.replace(
        r"\.1$",
        "",
        regex=True
    )

    # Make sure values are numeric
    # Invalid entries are converted to NaN and ignored by mean()
    shap_df = shap_df.apply(pd.to_numeric, errors="coerce")

    # Importance magnitude = mean absolute SHAP value across all samples
    importance_magnitude = shap_df.abs().mean(axis=0)

    # Create output table
    importance_table = pd.DataFrame({
        "Feature": importance_magnitude.index,
        "Importance Magnitude": importance_magnitude.values
    })

    # Sort from highest to lowest importance
    importance_table = importance_table.sort_values(
        by="Importance Magnitude",
        ascending=False,
        ignore_index=True
    )

    # Output file name
    output_path = input_folder / (
        f"importance_magnitude_mlp_Specificity_model_trial_{model_number}.csv"
    )

    importance_table.to_csv(output_path, index=False)

    print(f"Saved: {output_path.name}")

print("\nAll matching files have been processed.")
# Out:
# Detected 10 matching files:
# Model 38: shap_values_mlp_Specificity_model_trial_38.csv
# Model 46: shap_values_mlp_Specificity_model_trial_46.csv
# Model 47: shap_values_mlp_Specificity_model_trial_47.csv
# Model 52: shap_values_mlp_Specificity_model_trial_52.csv
# Model 54: shap_values_mlp_Specificity_model_trial_54.csv
# Model 57: shap_values_mlp_Specificity_model_trial_57.csv
# Model 59: shap_values_mlp_Specificity_model_trial_59.csv
# Model 75: shap_values_mlp_Specificity_model_trial_75.csv
# Model 77: shap_values_mlp_Specificity_model_trial_77.csv
# Model 95: shap_values_mlp_Specificity_model_trial_95.csv
#
# Processing model 38: shap_values_mlp_Specificity_model_trial_38.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_38.csv
#
# Processing model 46: shap_values_mlp_Specificity_model_trial_46.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_46.csv
#
# Processing model 47: shap_values_mlp_Specificity_model_trial_47.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_47.csv
#
# Processing model 52: shap_values_mlp_Specificity_model_trial_52.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_52.csv
#
# Processing model 54: shap_values_mlp_Specificity_model_trial_54.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_54.csv
#
# Processing model 57: shap_values_mlp_Specificity_model_trial_57.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_57.csv
#
# Processing model 59: shap_values_mlp_Specificity_model_trial_59.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_59.csv
#
# Processing model 75: shap_values_mlp_Specificity_model_trial_75.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_75.csv
#
# Processing model 77: shap_values_mlp_Specificity_model_trial_77.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_77.csv
#
# Processing model 95: shap_values_mlp_Specificity_model_trial_95.csv
# Saved: importance_magnitude_mlp_Specificity_model_trial_95.csv
#
# All matching files have been processed.
