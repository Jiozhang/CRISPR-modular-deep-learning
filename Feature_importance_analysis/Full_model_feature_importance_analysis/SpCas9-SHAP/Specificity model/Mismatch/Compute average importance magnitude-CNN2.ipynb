# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the importance-magnitude CSV files
input_folder = Path(".")

# Match files such as:
filename_pattern = re.compile(
    r"^importance_magnitude_cnn2_Specificity_model_mismatch_(\d+)\.csv$"
)

# Detect matching files
matching_files = []

for file_path in input_folder.glob(
    "importance_magnitude_cnn2_Specificity_model_mismatch_*.csv"
):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

# Sort by model number
matching_files.sort(key=lambda x: x[0])

print(f"Detected {len(matching_files)} importance-magnitude files:")

for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")

if len(matching_files) == 0:
    raise FileNotFoundError(
        "No matching importance-magnitude CSV files were found."
    )

if len(matching_files) != 10:
    print(
        f"\nWarning: Expected 10 files, but detected "
        f"{len(matching_files)} files."
    )


# Read and combine all files
all_importance_tables = []

for model_number, file_path in matching_files:

    df = pd.read_csv(file_path)

    # Check that the expected columns exist
    required_columns = {"Feature", "Importance Magnitude"}

    if not required_columns.issubset(df.columns):
        raise ValueError(
            f"{file_path.name} does not contain the required columns: "
            f"'Feature' and 'Importance Magnitude'."
        )

    # Keep only the required columns
    df = df[["Feature", "Importance Magnitude"]].copy()

    # Convert importance values to numeric
    df["Importance Magnitude"] = pd.to_numeric(
        df["Importance Magnitude"],
        errors="coerce"
    )

    # Add model number for tracking
    df["Model Number"] = model_number

    all_importance_tables.append(df)

# Combine all model tables
combined_df = pd.concat(
    all_importance_tables,
    ignore_index=True
)

# Calculate average importance magnitude for each feature
average_importance = (
    combined_df
    .groupby("Feature", as_index=False)
    .agg(
        Average_Importance_Magnitude=(
            "Importance Magnitude",
            "mean"
        ),
        Number_of_Models=(
            "Importance Magnitude",
            "count"
        )
    )
)

# Sort from highest to lowest average importance
average_importance = average_importance.sort_values(
    by="Average_Importance_Magnitude",
    ascending=False,
    ignore_index=True
)

# Save the final table
output_file = (
    input_folder /
    "average_importance_magnitude_cnn2_Specificity_model_mismatch.csv"
)

average_importance.to_csv(output_file, index=False)

print(f"\nSaved: {output_file.name}")
print("\nAverage importance magnitude table:")
print(average_importance)
# Out:
# Detected 10 importance-magnitude files:
# Model 38: importance_magnitude_cnn2_Specificity_model_mismatch_38.csv
# Model 46: importance_magnitude_cnn2_Specificity_model_mismatch_46.csv
# Model 47: importance_magnitude_cnn2_Specificity_model_mismatch_47.csv
# Model 52: importance_magnitude_cnn2_Specificity_model_mismatch_52.csv
# Model 54: importance_magnitude_cnn2_Specificity_model_mismatch_54.csv
# Model 57: importance_magnitude_cnn2_Specificity_model_mismatch_57.csv
# Model 59: importance_magnitude_cnn2_Specificity_model_mismatch_59.csv
# Model 75: importance_magnitude_cnn2_Specificity_model_mismatch_75.csv
# Model 77: importance_magnitude_cnn2_Specificity_model_mismatch_77.csv
# Model 95: importance_magnitude_cnn2_Specificity_model_mismatch_95.csv
#
# Saved: average_importance_magnitude_cnn2_Specificity_model_mismatch.csv
#
# Average importance magnitude table:
#                  Feature  Average_Importance_Magnitude  Number_of_Models
# 0         Pos15_Unpaired                  2.130359e-03                10
# 1          Pos6_Unpaired                  1.886166e-03                10
# 2          Pos7_Unpaired                  1.736990e-03                10
# 3   Pos15_Paired-Opening                  1.727273e-03                10
# 4         Pos14_Unpaired                  1.698131e-03                10
# 5          Pos8_Unpaired                  1.501555e-03                10
# 6   Pos14_Paired-Opening                  1.489198e-03                10
# 7          Pos5_Unpaired                  1.393422e-03                10
# 8    Pos6_Paired-Opening                  1.364271e-03                10
# 9          Pos4_Unpaired                  1.320399e-03                10
# 10        Pos17_Unpaired                  1.281253e-03                10
# 11   Pos7_Paired-Opening                  1.216162e-03                10
# 12         Pos9_Unpaired                  1.200365e-03                10
# 13   Pos8_Paired-Opening                  1.159471e-03                10
# 14  Pos17_Paired-Opening                  1.099115e-03                10
# 15   Pos5_Paired-Opening                  1.083925e-03                10
# 16   Pos4_Paired-Opening                  1.079617e-03                10
# 17        Pos19_Unpaired                  1.066065e-03                10
# 18        Pos10_Unpaired                  1.022490e-03                10
# 19        Pos16_Unpaired                  1.020682e-03                10
# 20   Pos9_Paired-Opening                  1.014978e-03                10
# 21         Pos3_Unpaired                  9.932566e-04                10
# 22  Pos10_Paired-Opening                  9.268936e-04                10
# 23        Pos20_Unpaired                  9.163425e-04                10
# 24        Pos18_Unpaired                  8.696229e-04                10
# 25  Pos19_Paired-Opening                  8.278945e-04                10
# 26         Pos1_Unpaired                  8.188341e-04                10
# 27        Pos12_Unpaired                  7.469990e-04                10
# 28  Pos18_Paired-Opening                  7.344759e-04                10
# 29   Pos1_Paired-Opening                  6.958637e-04                10
# 30   Pos3_Paired-Opening                  6.834104e-04                10
# 31        Pos11_Unpaired                  6.724839e-04                10
# 32  Pos12_Paired-Opening                  6.508584e-04                10
# 33  Pos11_Paired-Opening                  6.370766e-04                10
# 34        Pos13_Unpaired                  6.357921e-04                10
# 35  Pos16_Paired-Opening                  6.334257e-04                10
# 36  Pos13_Paired-Opening                  5.655269e-04                10
# 37  Pos20_Paired-Opening                  5.104322e-04                10
# 38         Pos2_Unpaired                  4.924813e-04                10
# 39   Pos2_Paired-Opening                  4.252388e-04                10
# 40  Pos17_Paired-Closing                  5.373226e-06                10
# 41  Pos19_Paired-Closing                  4.326821e-06                10
# 42  Pos16_Paired-Closing                  3.267629e-06                10
# 43  Pos18_Paired-Closing                  2.791319e-06                10
# 44  Pos14_Paired-Closing                  2.258199e-06                10
# 45  Pos20_Paired-Closing                  2.234448e-06                10
# 46  Pos15_Paired-Closing                  1.903325e-06                10
# 47  Pos13_Paired-Closing                  1.778934e-06                10
# 48  Pos11_Paired-Closing                  1.288651e-06                10
# 49  Pos12_Paired-Closing                  1.183145e-06                10
# 50   Pos9_Paired-Closing                  6.977540e-07                10
# 51  Pos10_Paired-Closing                  3.460390e-07                10
# 52   Pos7_Paired-Closing                  0.000000e+00                10
# 53   Pos6_Paired-Closing                  0.000000e+00                10
# 54   Pos8_Paired-Closing                  0.000000e+00                10
# 55   Pos5_Paired-Closing                  0.000000e+00                10
# 56   Pos4_Paired-Closing                  0.000000e+00                10
# 57   Pos3_Paired-Closing                  0.000000e+00                10
# 58   Pos2_Paired-Closing                  0.000000e+00                10
# 59   Pos1_Paired-Closing                  0.000000e+00                10

# %%
# PAM-order adjustment (reverse the order of the first 20 bases)
import pandas as pd
import re

# Input and output files
input_file = "average_importance_magnitude_cnn2_Specificity_model_mismatch.csv"
output_file = "PAM_adjusted_average_importance_magnitude_cnn2_Specificity_model_mismatch.csv"

# Read the CSV file
df = pd.read_csv(input_file)

# Function to adjust positions 1–20 only
def adjust_feature_position(feature):
    feature = str(feature).strip()

    # Match feature names such as Pos20_G
    match = re.match(r"^Pos(\d+)_(.+)$", feature)

    if not match:
        # Preserve feature names that do not follow the expected format
        return feature

    position = int(match.group(1))
    feature_type = match.group(2)

    # Reverse numbering only for the first 20 positions
    if 1 <= position <= 20:
        adjusted_position = 21 - position
        return f"Pos{adjusted_position}_{feature_type}"

    # Keep positions greater than 20 unchanged
    return feature


# Apply conversion to the Feature column
df["Feature"] = df["Feature"].apply(adjust_feature_position)

# Save the adjusted CSV file
df.to_csv(output_file, index=False)

print(f"Saved: {output_file}")
# Out:
# Saved: PAM_adjusted_average_importance_magnitude_cnn2_Specificity_model_mismatch.csv

# %%
import pandas as pd

# Read the average importance-magnitude CSV file
df = pd.read_csv("PAM_adjusted_average_importance_magnitude_cnn2_Specificity_model_mismatch.csv")

# Extract position and Struct from feature names
extracted = df["Feature"].str.extract(
    r"^Pos(\d+)_(Unpaired|Paired-Opening|Paired-Closing)$"
)

df["Position"] = pd.to_numeric(extracted[0], errors="coerce")
df["Struct"] = extracted[1]

# Ensure importance magnitudes are numeric
df["Average_Importance_Magnitude"] = pd.to_numeric(
    df["Average_Importance_Magnitude"],
    errors="coerce"
)

# Remove rows that don't match the expected format
df = df.dropna(
    subset=["Position", "Struct", "Average_Importance_Magnitude"]
).copy()

df["Position"] = df["Position"].astype(int)

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

Structs = ["Unpaired", "Paired-Opening", "Paired-Closing"]

results = []

for Struct in Structs:
    Struct_df = df[df["Struct"] == Struct]

    row = {"Struct": Struct}

    for window_name, (start, end) in windows.items():
        avg = Struct_df.loc[
            Struct_df["Position"].between(start, end),
            "Average_Importance_Magnitude"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

# Save as CSV
result_df.to_csv(
    "PAM_adjusted_average_importance_magnitude_by_Struct_position_range_cnn2_Specificity_model_mismatch.csv",
    index=False
)

print(result_df)
# Out:
#            Struct   First_6      Middle_8    Last_6
# 0        Unpaired  0.001214  1.151851e-03  0.001151
# 1  Paired-Opening  0.000922  9.575206e-04  0.000889
# 2  Paired-Closing  0.000003  9.440903e-07  0.000000
