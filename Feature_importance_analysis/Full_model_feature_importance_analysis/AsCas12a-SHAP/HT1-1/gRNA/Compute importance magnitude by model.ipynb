# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the SHAP CSV files
input_folder = Path(".")

# File-name pattern:
filename_pattern = re.compile(
    r"^shap_values_cnn1_HT11_(\d+)\.csv$"
)

# Find and sort all matching files by model number
matching_files = []

for file_path in input_folder.glob("shap_values_cnn1_HT11_*.csv"):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

matching_files.sort(key=lambda item: item[0])

print(f"Detected {len(matching_files)} matching files:")
for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")


# Process every detected CSV file
for model_number, input_path in matching_files:

    print(f"\nProcessing model {model_number}: {input_path.name}")

    # Pandas normally renames the second duplicate column:
    df = pd.read_csv(input_path)

    # Select the second occurrence of duplicated columns
    shap_df = df.loc[:, df.columns.str.endswith(".1")].copy()

    if shap_df.shape[1] == 0:
        print(
            f"Warning: No columns ending in '.1' were detected in "
            f"{input_path.name}. Skipping this file."
        )
        continue

    # Restore the original feature names
    shap_df.columns = shap_df.columns.str.replace(
        r"\.1$",
        "",
        regex=True
    )

    # Make sure values are numeric
    # Invalid entries are converted to NaN and ignored by mean()
    shap_df = shap_df.apply(pd.to_numeric, errors="coerce")

    # Importance magnitude = mean absolute SHAP value across all samples
    importance_magnitude = shap_df.abs().mean(axis=0)

    # Create output table
    importance_table = pd.DataFrame({
        "Feature": importance_magnitude.index,
        "Importance Magnitude": importance_magnitude.values
    })

    # Sort from highest to lowest importance
    importance_table = importance_table.sort_values(
        by="Importance Magnitude",
        ascending=False,
        ignore_index=True
    )

    # Output file name
    output_path = input_folder / (
        f"importance_magnitude_cnn1_HT11_{model_number}.csv"
    )

    importance_table.to_csv(output_path, index=False)

    print(f"Saved: {output_path.name}")

print("\nAll matching files have been processed.")
# Out:
# Detected 10 matching files:
# Model 6: shap_values_cnn1_HT11_6.csv
# Model 7: shap_values_cnn1_HT11_7.csv
# Model 31: shap_values_cnn1_HT11_31.csv
# Model 51: shap_values_cnn1_HT11_51.csv
# Model 70: shap_values_cnn1_HT11_70.csv
# Model 73: shap_values_cnn1_HT11_73.csv
# Model 76: shap_values_cnn1_HT11_76.csv
# Model 78: shap_values_cnn1_HT11_78.csv
# Model 88: shap_values_cnn1_HT11_88.csv
# Model 94: shap_values_cnn1_HT11_94.csv
#
# Processing model 6: shap_values_cnn1_HT11_6.csv
# Saved: importance_magnitude_cnn1_HT11_6.csv
#
# Processing model 7: shap_values_cnn1_HT11_7.csv
# Saved: importance_magnitude_cnn1_HT11_7.csv
#
# Processing model 31: shap_values_cnn1_HT11_31.csv
# Saved: importance_magnitude_cnn1_HT11_31.csv
#
# Processing model 51: shap_values_cnn1_HT11_51.csv
# Saved: importance_magnitude_cnn1_HT11_51.csv
#
# Processing model 70: shap_values_cnn1_HT11_70.csv
# Saved: importance_magnitude_cnn1_HT11_70.csv
#
# Processing model 73: shap_values_cnn1_HT11_73.csv
# Saved: importance_magnitude_cnn1_HT11_73.csv
#
# Processing model 76: shap_values_cnn1_HT11_76.csv
# Saved: importance_magnitude_cnn1_HT11_76.csv
#
# Processing model 78: shap_values_cnn1_HT11_78.csv
# Saved: importance_magnitude_cnn1_HT11_78.csv
#
# Processing model 88: shap_values_cnn1_HT11_88.csv
# Saved: importance_magnitude_cnn1_HT11_88.csv
#
# Processing model 94: shap_values_cnn1_HT11_94.csv
# Saved: importance_magnitude_cnn1_HT11_94.csv
#
# All matching files have been processed.

# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the SHAP CSV files
input_folder = Path(".")

# File-name pattern:
filename_pattern = re.compile(
    r"^shap_values_cnn2_HT11_(\d+)\.csv$"
)

# Find and sort all matching files by model number
matching_files = []

for file_path in input_folder.glob("shap_values_cnn2_HT11_*.csv"):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

matching_files.sort(key=lambda item: item[0])

print(f"Detected {len(matching_files)} matching files:")
for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")


# Process every detected CSV file
for model_number, input_path in matching_files:

    print(f"\nProcessing model {model_number}: {input_path.name}")

    # Pandas normally renames the second duplicate column:
    df = pd.read_csv(input_path)

    # Select the second occurrence of duplicated columns
    shap_df = df.loc[:, df.columns.str.endswith(".1")].copy()

    if shap_df.shape[1] == 0:
        print(
            f"Warning: No columns ending in '.1' were detected in "
            f"{input_path.name}. Skipping this file."
        )
        continue

    # Restore the original feature names
    shap_df.columns = shap_df.columns.str.replace(
        r"\.1$",
        "",
        regex=True
    )

    # Make sure values are numeric
    # Invalid entries are converted to NaN and ignored by mean()
    shap_df = shap_df.apply(pd.to_numeric, errors="coerce")

    # Importance magnitude = mean absolute SHAP value across all samples
    importance_magnitude = shap_df.abs().mean(axis=0)

    # Create output table
    importance_table = pd.DataFrame({
        "Feature": importance_magnitude.index,
        "Importance Magnitude": importance_magnitude.values
    })

    # Sort from highest to lowest importance
    importance_table = importance_table.sort_values(
        by="Importance Magnitude",
        ascending=False,
        ignore_index=True
    )

    # Output file name
    output_path = input_folder / (
        f"importance_magnitude_cnn2_HT11_{model_number}.csv"
    )

    importance_table.to_csv(output_path, index=False)

    print(f"Saved: {output_path.name}")

print("\nAll matching files have been processed.")
# Out:
# Detected 10 matching files:
# Model 6: shap_values_cnn2_HT11_6.csv
# Model 7: shap_values_cnn2_HT11_7.csv
# Model 31: shap_values_cnn2_HT11_31.csv
# Model 51: shap_values_cnn2_HT11_51.csv
# Model 70: shap_values_cnn2_HT11_70.csv
# Model 73: shap_values_cnn2_HT11_73.csv
# Model 76: shap_values_cnn2_HT11_76.csv
# Model 78: shap_values_cnn2_HT11_78.csv
# Model 88: shap_values_cnn2_HT11_88.csv
# Model 94: shap_values_cnn2_HT11_94.csv
#
# Processing model 6: shap_values_cnn2_HT11_6.csv
# Saved: importance_magnitude_cnn2_HT11_6.csv
#
# Processing model 7: shap_values_cnn2_HT11_7.csv
# Saved: importance_magnitude_cnn2_HT11_7.csv
#
# Processing model 31: shap_values_cnn2_HT11_31.csv
# Saved: importance_magnitude_cnn2_HT11_31.csv
#
# Processing model 51: shap_values_cnn2_HT11_51.csv
# Saved: importance_magnitude_cnn2_HT11_51.csv
#
# Processing model 70: shap_values_cnn2_HT11_70.csv
# Saved: importance_magnitude_cnn2_HT11_70.csv
#
# Processing model 73: shap_values_cnn2_HT11_73.csv
# Saved: importance_magnitude_cnn2_HT11_73.csv
#
# Processing model 76: shap_values_cnn2_HT11_76.csv
# Saved: importance_magnitude_cnn2_HT11_76.csv
#
# Processing model 78: shap_values_cnn2_HT11_78.csv
# Saved: importance_magnitude_cnn2_HT11_78.csv
#
# Processing model 88: shap_values_cnn2_HT11_88.csv
# Saved: importance_magnitude_cnn2_HT11_88.csv
#
# Processing model 94: shap_values_cnn2_HT11_94.csv
# Saved: importance_magnitude_cnn2_HT11_94.csv
#
# All matching files have been processed.

# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the SHAP CSV files
input_folder = Path(".")

# File-name pattern:
filename_pattern = re.compile(
    r"^shap_values_mlp_HT11_(\d+)\.csv$"
)

# Find and sort all matching files by model number
matching_files = []

for file_path in input_folder.glob("shap_values_mlp_HT11_*.csv"):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

matching_files.sort(key=lambda item: item[0])

print(f"Detected {len(matching_files)} matching files:")
for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")


# Process every detected CSV file
for model_number, input_path in matching_files:

    print(f"\nProcessing model {model_number}: {input_path.name}")

    # Pandas normally renames the second duplicate column:
    df = pd.read_csv(input_path)

    # Select the second occurrence of duplicated columns
    shap_df = df.loc[:, df.columns.str.endswith(".1")].copy()

    if shap_df.shape[1] == 0:
        print(
            f"Warning: No columns ending in '.1' were detected in "
            f"{input_path.name}. Skipping this file."
        )
        continue

    # Restore the original feature names
    shap_df.columns = shap_df.columns.str.replace(
        r"\.1$",
        "",
        regex=True
    )

    # Make sure values are numeric
    # Invalid entries are converted to NaN and ignored by mean()
    shap_df = shap_df.apply(pd.to_numeric, errors="coerce")

    # Importance magnitude = mean absolute SHAP value across all samples
    importance_magnitude = shap_df.abs().mean(axis=0)

    # Create output table
    importance_table = pd.DataFrame({
        "Feature": importance_magnitude.index,
        "Importance Magnitude": importance_magnitude.values
    })

    # Sort from highest to lowest importance
    importance_table = importance_table.sort_values(
        by="Importance Magnitude",
        ascending=False,
        ignore_index=True
    )

    # Output file name
    output_path = input_folder / (
        f"importance_magnitude_mlp_HT11_{model_number}.csv"
    )

    importance_table.to_csv(output_path, index=False)

    print(f"Saved: {output_path.name}")

print("\nAll matching files have been processed.")
# Out:
# Detected 10 matching files:
# Model 6: shap_values_mlp_HT11_6.csv
# Model 7: shap_values_mlp_HT11_7.csv
# Model 31: shap_values_mlp_HT11_31.csv
# Model 51: shap_values_mlp_HT11_51.csv
# Model 70: shap_values_mlp_HT11_70.csv
# Model 73: shap_values_mlp_HT11_73.csv
# Model 76: shap_values_mlp_HT11_76.csv
# Model 78: shap_values_mlp_HT11_78.csv
# Model 88: shap_values_mlp_HT11_88.csv
# Model 94: shap_values_mlp_HT11_94.csv
#
# Processing model 6: shap_values_mlp_HT11_6.csv
# Saved: importance_magnitude_mlp_HT11_6.csv
#
# Processing model 7: shap_values_mlp_HT11_7.csv
# Saved: importance_magnitude_mlp_HT11_7.csv
#
# Processing model 31: shap_values_mlp_HT11_31.csv
# Saved: importance_magnitude_mlp_HT11_31.csv
#
# Processing model 51: shap_values_mlp_HT11_51.csv
# Saved: importance_magnitude_mlp_HT11_51.csv
#
# Processing model 70: shap_values_mlp_HT11_70.csv
# Saved: importance_magnitude_mlp_HT11_70.csv
#
# Processing model 73: shap_values_mlp_HT11_73.csv
# Saved: importance_magnitude_mlp_HT11_73.csv
#
# Processing model 76: shap_values_mlp_HT11_76.csv
# Saved: importance_magnitude_mlp_HT11_76.csv
#
# Processing model 78: shap_values_mlp_HT11_78.csv
# Saved: importance_magnitude_mlp_HT11_78.csv
#
# Processing model 88: shap_values_mlp_HT11_88.csv
# Saved: importance_magnitude_mlp_HT11_88.csv
#
# Processing model 94: shap_values_mlp_HT11_94.csv
# Saved: importance_magnitude_mlp_HT11_94.csv
#
# All matching files have been processed.
