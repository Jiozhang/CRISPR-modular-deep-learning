# %%
from pathlib import Path
import re
import pandas as pd

# Folder containing the importance-magnitude CSV files
input_folder = Path(".")

# Match files such as:
filename_pattern = re.compile(
    r"^importance_magnitude_cnn2_HT11_ssDNA_target_ah_(\d+)\.csv$"
)

# Detect matching files
matching_files = []

for file_path in input_folder.glob(
    "importance_magnitude_cnn2_HT11_ssDNA_target_ah_*.csv"
):
    match = filename_pattern.match(file_path.name)

    if match:
        model_number = int(match.group(1))
        matching_files.append((model_number, file_path))

# Sort by model number
matching_files.sort(key=lambda x: x[0])

print(f"Detected {len(matching_files)} importance-magnitude files:")

for model_number, file_path in matching_files:
    print(f"Model {model_number}: {file_path.name}")

if len(matching_files) == 0:
    raise FileNotFoundError(
        "No matching importance-magnitude CSV files were found."
    )

if len(matching_files) != 10:
    print(
        f"\nWarning: Expected 10 files, but detected "
        f"{len(matching_files)} files."
    )


# Read and combine all files
all_importance_tables = []

for model_number, file_path in matching_files:

    df = pd.read_csv(file_path)

    # Check that the expected columns exist
    required_columns = {"Feature", "Importance Magnitude"}

    if not required_columns.issubset(df.columns):
        raise ValueError(
            f"{file_path.name} does not contain the required columns: "
            f"'Feature' and 'Importance Magnitude'."
        )

    # Keep only the required columns
    df = df[["Feature", "Importance Magnitude"]].copy()

    # Convert importance values to numeric
    df["Importance Magnitude"] = pd.to_numeric(
        df["Importance Magnitude"],
        errors="coerce"
    )

    # Add model number for tracking
    df["Model Number"] = model_number

    all_importance_tables.append(df)

# Combine all model tables
combined_df = pd.concat(
    all_importance_tables,
    ignore_index=True
)

# Calculate average importance magnitude for each feature
average_importance = (
    combined_df
    .groupby("Feature", as_index=False)
    .agg(
        Average_Importance_Magnitude=(
            "Importance Magnitude",
            "mean"
        ),
        Number_of_Models=(
            "Importance Magnitude",
            "count"
        )
    )
)

# Sort from highest to lowest average importance
average_importance = average_importance.sort_values(
    by="Average_Importance_Magnitude",
    ascending=False,
    ignore_index=True
)

# Save the final table
output_file = (
    input_folder /
    "average_importance_magnitude_cnn2_HT11_ssDNA_target_ah.csv"
)

average_importance.to_csv(output_file, index=False)

print(f"\nSaved: {output_file.name}")
print("\nAverage importance magnitude table:")
print(average_importance)
# Out:
# Detected 10 importance-magnitude files:
# Model 6: importance_magnitude_cnn2_HT11_ssDNA_target_ah_6.csv
# Model 7: importance_magnitude_cnn2_HT11_ssDNA_target_ah_7.csv
# Model 31: importance_magnitude_cnn2_HT11_ssDNA_target_ah_31.csv
# Model 51: importance_magnitude_cnn2_HT11_ssDNA_target_ah_51.csv
# Model 70: importance_magnitude_cnn2_HT11_ssDNA_target_ah_70.csv
# Model 73: importance_magnitude_cnn2_HT11_ssDNA_target_ah_73.csv
# Model 76: importance_magnitude_cnn2_HT11_ssDNA_target_ah_76.csv
# Model 78: importance_magnitude_cnn2_HT11_ssDNA_target_ah_78.csv
# Model 88: importance_magnitude_cnn2_HT11_ssDNA_target_ah_88.csv
# Model 94: importance_magnitude_cnn2_HT11_ssDNA_target_ah_94.csv
#
# Saved: average_importance_magnitude_cnn2_HT11_ssDNA_target_ah.csv
#
# Average importance magnitude table:
#                  Feature  Average_Importance_Magnitude  Number_of_Models
# 0          Pos4_Unpaired                      0.001105                10
# 1         Pos16_Unpaired                      0.001072                10
# 2    Pos4_Paired-Opening                      0.000998                10
# 3         Pos12_Unpaired                      0.000983                10
# 4   Pos16_Paired-Closing                      0.000890                10
# 5         Pos17_Unpaired                      0.000882                10
# 6         Pos13_Unpaired                      0.000866                10
# 7   Pos17_Paired-Closing                      0.000783                10
# 8   Pos15_Paired-Closing                      0.000760                10
# 9         Pos11_Unpaired                      0.000726                10
# 10  Pos14_Paired-Closing                      0.000725                10
# 11  Pos13_Paired-Closing                      0.000717                10
# 12        Pos15_Unpaired                      0.000677                10
# 13         Pos5_Unpaired                      0.000656                10
# 14        Pos14_Unpaired                      0.000648                10
# 15   Pos5_Paired-Opening                      0.000553                10
# 16         Pos2_Unpaired                      0.000520                10
# 17  Pos12_Paired-Closing                      0.000515                10
# 18        Pos18_Unpaired                      0.000486                10
# 19         Pos1_Unpaired                      0.000465                10
# 20  Pos18_Paired-Closing                      0.000457                10
# 21   Pos7_Paired-Opening                      0.000437                10
# 22        Pos10_Unpaired                      0.000427                10
# 23         Pos3_Unpaired                      0.000417                10
# 24   Pos2_Paired-Opening                      0.000414                10
# 25   Pos1_Paired-Opening                      0.000400                10
# 26        Pos19_Unpaired                      0.000389                10
# 27   Pos8_Paired-Opening                      0.000387                10
# 28   Pos3_Paired-Opening                      0.000380                10
# 29         Pos7_Unpaired                      0.000370                10
# 30   Pos9_Paired-Opening                      0.000336                10
# 31  Pos11_Paired-Closing                      0.000333                10
# 32  Pos19_Paired-Closing                      0.000326                10
# 33   Pos6_Paired-Opening                      0.000316                10
# 34  Pos10_Paired-Opening                      0.000310                10
# 35         Pos6_Unpaired                      0.000306                10
# 36  Pos11_Paired-Opening                      0.000244                10
# 37         Pos8_Unpaired                      0.000215                10
# 38  Pos12_Paired-Opening                      0.000197                10
# 39         Pos9_Unpaired                      0.000175                10
# 40        Pos20_Unpaired                      0.000157                10
# 41  Pos10_Paired-Closing                      0.000150                10
# 42  Pos20_Paired-Closing                      0.000106                10
# 43  Pos13_Paired-Opening                      0.000053                10
# 44   Pos9_Paired-Closing                      0.000041                10
# 45   Pos8_Paired-Closing                      0.000019                10
# 46  Pos14_Paired-Opening                      0.000004                10
# 47   Pos7_Paired-Closing                      0.000002                10
# 48  Pos17_Paired-Opening                      0.000000                10
# 49  Pos15_Paired-Opening                      0.000000                10
# 50  Pos16_Paired-Opening                      0.000000                10
# 51   Pos4_Paired-Closing                      0.000000                10
# 52   Pos3_Paired-Closing                      0.000000                10
# 53  Pos18_Paired-Opening                      0.000000                10
# 54  Pos19_Paired-Opening                      0.000000                10
# 55   Pos6_Paired-Closing                      0.000000                10
# 56  Pos20_Paired-Opening                      0.000000                10
# 57   Pos5_Paired-Closing                      0.000000                10
# 58   Pos2_Paired-Closing                      0.000000                10
# 59   Pos1_Paired-Closing                      0.000000                10

# %%
import pandas as pd

# Read the average importance-magnitude CSV file
df = pd.read_csv("average_importance_magnitude_cnn2_HT11_ssDNA_target_ah.csv")

# Extract position and Struct from feature names
extracted = df["Feature"].str.extract(
    r"^Pos(\d+)_(Unpaired|Paired-Opening|Paired-Closing)$"
)

df["Position"] = pd.to_numeric(extracted[0], errors="coerce")
df["Struct"] = extracted[1]

# Ensure importance magnitudes are numeric
df["Average_Importance_Magnitude"] = pd.to_numeric(
    df["Average_Importance_Magnitude"],
    errors="coerce"
)

# Remove rows that don't match the expected format
df = df.dropna(
    subset=["Position", "Struct", "Average_Importance_Magnitude"]
).copy()

df["Position"] = df["Position"].astype(int)

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

Structs = ["Unpaired", "Paired-Opening", "Paired-Closing"]

results = []

for Struct in Structs:
    Struct_df = df[df["Struct"] == Struct]

    row = {"Struct": Struct}

    for window_name, (start, end) in windows.items():
        avg = Struct_df.loc[
            Struct_df["Position"].between(start, end),
            "Average_Importance_Magnitude"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

# Save as CSV
result_df.to_csv(
    "average_importance_magnitude_by_Struct_position_range_cnn2_HT11_ssDNA_target_ah.csv",
    index=False
)

print(result_df)
# Out:
#            Struct   First_6  Middle_8    Last_6
# 0        Unpaired  0.000578  0.000551  0.000611
# 1  Paired-Opening  0.000510  0.000246  0.000000
# 2  Paired-Closing  0.000000  0.000313  0.000554
