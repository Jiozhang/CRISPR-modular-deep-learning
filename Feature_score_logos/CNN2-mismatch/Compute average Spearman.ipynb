# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_computed_spearman_by_struct_position_mismatch.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (15, 20),
    "Middle_8": (7, 14),
    "Last_6": (1, 6)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_8    Last_6
# 0      U -0.768000 -0.778250 -0.680667
# 1      O  0.780333  0.732625  0.616500
# 2      C  0.059500  0.000000  0.000000

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("LbCas12a_computed_spearman_by_struct_position_mismatch.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_9": (7, 15),
    "Last_6": (16, 21)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_9    Last_6
# 0      U -0.346500 -0.553333 -0.337167
# 1      O  0.312667  0.387667  0.299833
# 2      C -0.500000  0.000000  0.000000

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("RfxCas13d_computed_spearman_by_struct_position_mismatch.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_11": (7, 17),
    "Last_6": (18, 23)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_11    Last_6
# 0      U -0.923167  -0.755455 -0.909833
# 1      O  0.822333   0.755455  0.901667
# 2      C  0.000000   0.000000  0.000000
