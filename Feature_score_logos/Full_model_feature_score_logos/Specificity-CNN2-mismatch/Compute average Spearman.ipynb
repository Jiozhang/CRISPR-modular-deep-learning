# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_Specificity_model_computed_spearman_by_struct_position_mismatch.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (15, 20),
    "Middle_8": (7, 14),
    "Last_6": (1, 6)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_8    Last_6
# 0      U  0.691833  0.577375  0.531833
# 1      O -0.638833 -0.523500 -0.391167
# 2      C -0.261833  0.125000  0.000000

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("LbCas12a_Specificity_model_computed_spearman_by_struct_position_mismatch.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_9": (7, 15),
    "Last_6": (16, 21)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_9    Last_6
# 0      U  0.341500  0.503556  0.253500
# 1      O -0.346500 -0.503111 -0.260833
# 2      C  0.333333  0.000000  0.000000
