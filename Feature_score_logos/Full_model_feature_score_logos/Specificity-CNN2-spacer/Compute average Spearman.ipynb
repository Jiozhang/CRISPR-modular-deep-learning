# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_Specificity_model_computed_spearman_by_struct_position_spacer.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (15, 20),
    "Middle_8": (7, 14),
    "Last_6": (1, 6)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_8  Last_6
# 0      U -0.392667 -0.074875   0.117
# 1      O  0.082500  0.045750   0.000
# 2      C  0.635667 -0.008875  -0.155

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("LbCas12a_Specificity_model_computed_spearman_by_struct_position_spacer.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (22, 27),
    "Middle_9": (28, 36),
    "Last_6": (37, 42)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_9    Last_6
# 0      U -0.188833  0.038778 -0.176333
# 1      O -0.143000  0.051444  0.000000
# 2      C  0.178667  0.198222  0.167500
