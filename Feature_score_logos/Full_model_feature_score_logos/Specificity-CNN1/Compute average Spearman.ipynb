# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_Specificity_model_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

bases = ["A", "C", "G", "T"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base  First_6  Middle_8  Last_6
# 0    A   0.5850  0.668125  0.6898
# 1    C  -0.4080 -0.180625 -0.0698
# 2    G  -0.1775  0.024375 -0.3392
# 3    T  -0.0380 -0.583875 -0.3946

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("LbCas12a_Specificity_model_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

windows = {
    "First_6": (1, 6),
    "Middle_9": (7, 15),
    "Last_6": (16, 21)
}

bases = ["A", "C", "G", "T"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base   First_6  Middle_9    Last_6
# 0    A  0.709833  0.739778  0.689167
# 1    C  0.339000  0.209556  0.160333
# 2    G -0.720167 -0.625111 -0.588833
# 3    T  0.224500 -0.209889 -0.297667
