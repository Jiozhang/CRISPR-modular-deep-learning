# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_computed_spearman_by_struct_position_spacer.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (15, 20),
    "Middle_8": (7, 14),
    "Last_6": (1, 6)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_8    Last_6
# 0      U  0.674333  0.082875 -0.270500
# 1      O -0.366333 -0.189625  0.000000
# 2      C -0.325500  0.247000  0.258333

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("AsCas12a_computed_spearman_by_struct_position_spacer.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (21, 26),
    "Middle_8": (27, 34),
    "Last_6": (35, 40)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_8  Last_6
# 0      U  0.155000  0.152000  0.1435
# 1      O -0.294833 -0.091375  0.0000
# 2      C -0.045667 -0.245000 -0.3075

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("RfxCas13d_validation_computed_spearman_by_struct_position_spacer.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (37, 42),
    "Middle_18": (43, 60),
    "Last_6": (61, 66)
}

structs = ["U", "O", "C"]

results = []

for struct in structs:
    struct_df = df[df["Struct"] == struct]

    row = {"Struct": struct}

    for window_name, (start, end) in windows.items():
        avg = struct_df.loc[
            struct_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Struct   First_6  Middle_18    Last_6
# 0      U -0.266667  -0.092500  0.096333
# 1      O  0.229500   0.081722  0.000000
# 2      C  0.107500  -0.066833  0.072500
