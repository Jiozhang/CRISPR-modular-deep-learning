# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

bases = ["A", "C", "G", "T"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base   First_6  Middle_8    Last_6
# 0    A  0.111833  0.486500  0.509167
# 1    C  0.330333  0.520125  0.185667
# 2    G  0.511667  0.230250  0.468167
# 3    T -0.486167 -0.252500 -0.124833

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("AsCas12a_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

bases = ["A", "C", "G", "T"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base   First_6  Middle_8    Last_6
# 0    A -0.014167  0.440750  0.519833
# 1    C  0.110667  0.751000  0.430333
# 2    G  0.569333  0.329500 -0.310000
# 3    T -0.378333 -0.533625  0.065000

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("RfxCas13d_validation_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_18": (7, 24),
    "Last_6": (25, 30)
}

bases = ["A", "C", "G", "U"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base   First_6  Middle_18    Last_6
# 0    A  0.243000  -0.110500  0.232000
# 1    C  0.138167  -0.033111 -0.189833
# 2    G -0.101833   0.004722 -0.460167
# 3    U -0.385167  -0.045500  0.139833
