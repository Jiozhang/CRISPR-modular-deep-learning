# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("SpCas9_indiv_Specificity_model_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

# Define windows
windows = {
    "First_6": (1, 6),
    "Middle_8": (7, 14),
    "Last_6": (15, 20)
}

bases = ["A", "C", "G", "T"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base   First_6  Middle_8  Last_6
# 0    A  0.585000  0.618875  0.6172
# 1    C -0.396833  0.071125  0.3484
# 2    G -0.441000 -0.096125 -0.7092
# 3    T  0.201167 -0.291875 -0.4520

# %%
import pandas as pd

# Read CSV file
df = pd.read_csv("LbCas12a_indiv_Specificity_model_computed_spearman_by_base_position.csv")

# Ensure correct data types
df["Position"] = pd.to_numeric(df["Position"])
df["Computed_Spearman"] = pd.to_numeric(df["Computed_Spearman"])

windows = {
    "First_6": (1, 6),
    "Middle_9": (7, 15),
    "Last_6": (16, 21)
}

bases = ["A", "C", "G", "T"]

results = []

for base in bases:
    base_df = df[df["Base"] == base]

    row = {"Base": base}

    for window_name, (start, end) in windows.items():
        avg = base_df.loc[
            base_df["Position"].between(start, end),
            "Computed_Spearman"
        ].mean()

        row[window_name] = avg

    results.append(row)

# Convert to DataFrame
result_df = pd.DataFrame(results)

print(result_df)
# Out:
#   Base   First_6  Middle_9    Last_6
# 0    A  0.719833  0.753778  0.730000
# 1    C -0.176000 -0.210889  0.128167
# 2    G -0.720167 -0.537222 -0.593333
# 3    T  0.641167 -0.105889 -0.425500
