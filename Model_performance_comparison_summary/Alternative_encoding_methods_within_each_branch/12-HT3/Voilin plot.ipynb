# %%
import numpy as np
import matplotlib.pyplot as plt

files = [
    "Validation_loss_FULL_CNN1_token.txt",
    "Validation_loss_FULL_CNN2_token.txt",
    "Validation_loss_FULL_MLP_conventional.txt",
    "Validation_loss_FULL_GNN_reduced.txt",
    "Validation_loss_FULL.txt"
]

labels = [
    "Alternative CNN1",
    "Alternative CNN2",
    "Alternative MLP",
    "Alternative GNN",
    "Original model"
]

groups = []
for file in files:
    data = np.loadtxt(file)
    data = data[np.isfinite(data)]   # remove NaN and inf
    groups.append(data)

# Normalize using global min and max across all five groups
all_values = np.concatenate(groups)
vmin = all_values.min()
vmax = all_values.max()

groups_norm = [(g - vmin) / (vmax - vmin) for g in groups]

plt.rcParams.update({
    "font.family": "Arial",
    "font.size": 20,
    "axes.linewidth": 1.5,
    "xtick.major.width": 1.5,
    "ytick.major.width": 1.5,
})

fig, ax = plt.subplots(figsize=(9, 6), dpi=600)

parts = ax.violinplot(
    groups_norm,
    positions=np.arange(1, len(groups_norm) + 1),
    widths=0.7,
    showmeans=False,
    showmedians=True,
    showextrema=False,
    quantiles=[[0.25, 0.75]] * len(groups_norm)
)

for body in parts["bodies"]:
    body.set_facecolor("#4C72B0")
    body.set_edgecolor("black")
    body.set_alpha(0.35)
    body.set_linewidth(1.4)

parts["cmedians"].set_color("black")
parts["cmedians"].set_linewidth(2)

parts["cquantiles"].set_color("black")
parts["cquantiles"].set_linestyle("--")
parts["cquantiles"].set_linewidth(1.2)

rng = np.random.default_rng(42)

for i, data in enumerate(groups_norm, start=1):
    x = rng.normal(i, 0.045, len(data))
    ax.scatter(
        x,
        data,
        s=18,
        color="black",
        alpha=0.45,
        zorder=3
    )

ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels, rotation=25, ha="right")

ax.set_ylabel("Normalized Validation Loss", fontsize=24)
ax.set_ylim(-0.02, 1.02)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.grid(axis="y", linestyle="--", alpha=0.3)

plt.tight_layout()
plt.savefig("Validation_loss_five_groups_violin_plot.png", dpi=600, bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

files = [
    "Pearson_FULL_CNN1_token.txt",
    "Pearson_FULL_CNN2_token.txt",
    "Pearson_FULL_MLP_conventional.txt",
    "Pearson_FULL_GNN_reduced.txt",
    "Pearson_FULL.txt"
]

labels = [
    "Alternative CNN1",
    "Alternative CNN2",
    "Alternative MLP",
    "Alternative GNN",
    "Original model"
]

groups = []
for file in files:
    data = np.loadtxt(file)
    data = data[np.isfinite(data)]   # remove NaN and inf
    groups.append(data)

# Normalize using global min and max across all five groups
all_values = np.concatenate(groups)
vmin = all_values.min()
vmax = all_values.max()

groups_norm = [(g - vmin) / (vmax - vmin) for g in groups]

plt.rcParams.update({
    "font.family": "Arial",
    "font.size": 20,
    "axes.linewidth": 1.5,
    "xtick.major.width": 1.5,
    "ytick.major.width": 1.5,
})

fig, ax = plt.subplots(figsize=(9, 6), dpi=600)

parts = ax.violinplot(
    groups_norm,
    positions=np.arange(1, len(groups_norm) + 1),
    widths=0.7,
    showmeans=False,
    showmedians=True,
    showextrema=False,
    quantiles=[[0.25, 0.75]] * len(groups_norm)
)

for body in parts["bodies"]:
    body.set_facecolor("#4C72B0")
    body.set_edgecolor("black")
    body.set_alpha(0.35)
    body.set_linewidth(1.4)

parts["cmedians"].set_color("black")
parts["cmedians"].set_linewidth(2)

parts["cquantiles"].set_color("black")
parts["cquantiles"].set_linestyle("--")
parts["cquantiles"].set_linewidth(1.2)

rng = np.random.default_rng(42)

for i, data in enumerate(groups_norm, start=1):
    x = rng.normal(i, 0.045, len(data))
    ax.scatter(
        x,
        data,
        s=18,
        color="black",
        alpha=0.45,
        zorder=3
    )

ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels, rotation=25, ha="right")

ax.set_ylabel("Normalized Pearson's\ncorrelation coefficient", fontsize=24)
ax.set_ylim(-0.02, 1.02)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.grid(axis="y", linestyle="--", alpha=0.3)

plt.tight_layout()
plt.savefig("Pearson_five_groups_violin_plot.png", dpi=600, bbox_inches="tight")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

files = [
    "Spearman_FULL_CNN1_token.txt",
    "Spearman_FULL_CNN2_token.txt",
    "Spearman_FULL_MLP_conventional.txt",
    "Spearman_FULL_GNN_reduced.txt",
    "Spearman_FULL.txt"
]

labels = [
    "Alternative CNN1",
    "Alternative CNN2",
    "Alternative MLP",
    "Alternative GNN",
    "Original model"
]

groups = []
for file in files:
    data = np.loadtxt(file)
    data = data[np.isfinite(data)]   # remove NaN and inf
    groups.append(data)

# Normalize using global min and max across all five groups
all_values = np.concatenate(groups)
vmin = all_values.min()
vmax = all_values.max()

groups_norm = [(g - vmin) / (vmax - vmin) for g in groups]

plt.rcParams.update({
    "font.family": "Arial",
    "font.size": 20,
    "axes.linewidth": 1.5,
    "xtick.major.width": 1.5,
    "ytick.major.width": 1.5,
})

fig, ax = plt.subplots(figsize=(9, 6), dpi=600)

parts = ax.violinplot(
    groups_norm,
    positions=np.arange(1, len(groups_norm) + 1),
    widths=0.7,
    showmeans=False,
    showmedians=True,
    showextrema=False,
    quantiles=[[0.25, 0.75]] * len(groups_norm)
)

for body in parts["bodies"]:
    body.set_facecolor("#4C72B0")
    body.set_edgecolor("black")
    body.set_alpha(0.35)
    body.set_linewidth(1.4)

parts["cmedians"].set_color("black")
parts["cmedians"].set_linewidth(2)

parts["cquantiles"].set_color("black")
parts["cquantiles"].set_linestyle("--")
parts["cquantiles"].set_linewidth(1.2)

rng = np.random.default_rng(42)

for i, data in enumerate(groups_norm, start=1):
    x = rng.normal(i, 0.045, len(data))
    ax.scatter(
        x,
        data,
        s=18,
        color="black",
        alpha=0.45,
        zorder=3
    )

ax.set_xticks(np.arange(1, len(labels) + 1))
ax.set_xticklabels(labels, rotation=25, ha="right")

ax.set_ylabel("Normalized Spearman's\ncorrelation coefficient", fontsize=24)
ax.set_ylim(-0.02, 1.02)

ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

ax.grid(axis="y", linestyle="--", alpha=0.3)

plt.tight_layout()
plt.savefig("Spearman_five_groups_violin_plot.png", dpi=600, bbox_inches="tight")
plt.show()
