# %%
def DNA_to_RNA(DNA):
    match = {'A': 'A', 'C': 'C', 'G': 'G', 'T': 'U'}
    return ''.join(match.get(base, base) for base in (DNA))

def append_sequence_to_file(input_file, output_file):
    suffix = "GUUUAAGAGCUAUGCUGGAAACAGCAUAGCAAGUUUAAAUAAGGCUAGUCCGUUAUCAACUUGAAAAAGUGGCACCGAGUCGGUGCUUUU"

    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            sequence = line.strip()  # Remove newline and surrounding whitespace
            if sequence:  # Skip empty lines if desired
                outfile.write(DNA_to_RNA(sequence) + suffix + "\n")
            else:
                outfile.write("\n")  # Preserve empty lines

# Example usage
input_file = "test_sgRNA_sequences.txt"
output_file = "test_full_size_sgRNA_sequences.txt"

append_sequence_to_file(input_file, output_file)

print("finished")

# %%
def DNA_to_RNA(DNA):
    match = {'A': 'A', 'C': 'C', 'G': 'G', 'T': 'U'}
    return ''.join(match.get(base, base) for base in (DNA))

def append_sequence_to_file(input_file, output_file):
    suffix = "GUUUAAGAGCUAUGCUGGAAACAGCAUAGCAAGUUUAAAUAAGGCUAGUCCGUUAUCAACUUGAAAAAGUGGCACCGAGUCGGUGCUUUU"

    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            sequence = line.strip()  # Remove newline and surrounding whitespace
            if sequence:  # Skip empty lines if desired
                outfile.write(DNA_to_RNA(sequence) + suffix + "\n")
            else:
                outfile.write("\n")  # Preserve empty lines

# Example usage
input_file = "train_sgRNA_sequences.txt"
output_file = "train_full_size_sgRNA_sequences.txt"

append_sequence_to_file(input_file, output_file)

print("finished")

# %%
def DNA_to_RNA(DNA):
    match = {'A': 'A', 'C': 'C', 'G': 'G', 'T': 'U'}
    return ''.join(match.get(base, base) for base in (DNA))

def append_sequence_to_file(input_file, output_file):
    suffix = "GUUUAAGAGCUAUGCUGGAAACAGCAUAGCAAGUUUAAAUAAGGCUAGUCCGUUAUCAACUUGAAAAAGUGGCACCGAGUCGGUGCUUUU"

    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            sequence = line.strip()  # Remove newline and surrounding whitespace
            if sequence:  # Skip empty lines if desired
                outfile.write(DNA_to_RNA(sequence) + suffix + "\n")
            else:
                outfile.write("\n")  # Preserve empty lines

# Example usage
input_file = "unseen_sgRNA_sequences.txt"
output_file = "unseen_full_size_sgRNA_sequences.txt"

append_sequence_to_file(input_file, output_file)

print("finished")
