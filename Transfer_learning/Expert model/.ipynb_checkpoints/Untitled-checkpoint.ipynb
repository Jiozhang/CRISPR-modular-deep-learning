# %%
import os

ROOT = "Test on prime editing"
TARGET = "combined_preds"
NEW_NAME = "preds_Generalist.txt"

renamed = 0
skipped = 0
errors = 0

for root, _, files in os.walk(ROOT):
    for fname in files:
        if not fname.lower().endswith(".txt"):
            continue

        # tolerate stray quotes in filenames
        fname_no_quotes = fname.replace('"', "").replace("'", "")

        if TARGET not in fname and TARGET not in fname_no_quotes:
            continue

        old_path = os.path.join(root, fname)
        new_path = os.path.join(root, NEW_NAME)

        # already correct name
        if os.path.abspath(old_path) == os.path.abspath(new_path):
            skipped += 1
            continue

        # do NOT overwrite existing Feature_CNN1_reduced.txt
        if os.path.exists(new_path):
            print(f"SKIP (exists): {new_path}  <-- would overwrite from {old_path}")
            skipped += 1
            continue

        try:
            os.rename(old_path, new_path)
            print(f"RENAMED: {old_path} -> {new_path}")
            renamed += 1
        except Exception as e:
            print(f"ERROR: {old_path} -> {new_path} | {e}")
            errors += 1

print("\nSummary")
print(f"Renamed: {renamed}")
print(f"Skipped: {skipped}")
print(f"Errors:  {errors}")
# Out:
# RENAMED: Test on prime editing/HEK293T_PE2/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_HEK293T_PE2.txt -> Test on prime editing/HEK293T_PE2/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/HCT116_PE2/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_HCT116_PE2.txt -> Test on prime editing/HCT116_PE2/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/HeLa_PE2max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_HeLa_PE2max.txt -> Test on prime editing/HeLa_PE2max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/A549_PE2max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_A549_PE2max.txt -> Test on prime editing/A549_PE2max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/MDA_MB_231_PE2/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_MDA_MB_231_PE2.txt -> Test on prime editing/MDA_MB_231_PE2/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/HEK293T_PE2max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_HEK293T_PE2max.txt -> Test on prime editing/HEK293T_PE2max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/DLD1_PE4max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_DLD1_PE4max.txt -> Test on prime editing/DLD1_PE4max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/A549_PE4max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_A549_PE4max.txt -> Test on prime editing/A549_PE4max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/HEK293T_PE4max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_HEK293T_PE4max.txt -> Test on prime editing/HEK293T_PE4max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/DLD1_PE2max/Zero-shot prediction/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_DLD1_PE2max.txt -> Test on prime editing/DLD1_PE2max/Zero-shot prediction/preds_Generalist.txt
# RENAMED: Test on prime editing/DLD1_PE2max/Zero-shot prediction/.ipynb_checkpoints/HTCas9_HT11_RfxCas13d_change_seq_sampled_2_tiger_iMeta_combined_preds_Library_Small_DLD1_PE2max-checkpoint.txt -> Test on prime editing/DLD1_PE2max/Zero-shot prediction/.ipynb_checkpoints/preds_Generalist.txt
#
# Summary
# Renamed: 11
# Skipped: 0
# Errors:  0

# %%
quarter 
one_eighth
one_sixteenth

baseonly    Feature_CNN1_reduced
struct_only_bhah    Feature_CNN2_reduced
target_complete_value    Feature_MLP_expanded



iMeta_combined_L2_DROPOUT_reduced_feature_120D_all_positive_MLP_all    best_7_dataset_trained_FULL
tiger_combined_L2_DROPOUT_reduced_feature_120D_all_positive_MLP_all    best_6_dataset_trained_FULL
change_seq_sampled_2_combined_L2_DROPOUT_reduced_feature_120D_all_positive_MLP_all    best_5_dataset_trained_FULL
RfxCas13d_combined_L2_DROPOUT_reduced_feature_120D_all_positive_MLP_all    best_4_dataset_trained_FULL
HT11_combined_L2_DROPOUT_reduced_feature_120D_all_positive_MLP_all    best_2_dataset_trained_FULL
HTCas9_combined_L2_DROPOUT_reduced_feature_120D_all_positive_MLP_all    best_1_dataset_trained_FULL


iMeta_combined_unique_CNN1_only_reduced_feature    best_7_dataset_trained_CNN1
tiger_combined_unique_CNN1_only_reduced_feature    best_6_dataset_trained_CNN1
change_seq_sampled_2_combined_unique_CNN1_only_reduced_feature    best_5_dataset_trained_CNN1
RfxCas13d_combined_unique_CNN1_only_reduced_feature    best_4_dataset_trained_CNN1
HT11_combined_unique_CNN1_only_reduced_feature    best_2_dataset_trained_CNN1
HTCas9_combined_unique_CNN1_only_reduced_feature    best_1_dataset_trained_CNN1

iMeta_combined_preds    preds_7_dataset_trained_FULL
tiger_combined_preds    preds_6_dataset_trained_FULL
change_seq_combined_preds    preds_5_dataset_trained_FULL
RfxCas13d_combined_preds    preds_4_dataset_trained_FULL
HT11_combined_preds    preds_2_dataset_trained_FULL
HTCas9_combined_preds    preds_1_dataset_trained_FULL

# %%
import os
import re
import nbformat

ROOT = "Test on prime editing"

pattern = re.compile(r'["\'][^"\']*combined_preds[^"\']*\.txt["\']')
replacement = '"preds_Generalist.txt"'

total_changes = 0
files_modified = 0

for root, _, files in os.walk(ROOT):
    for fn in files:
        if not fn.endswith(".ipynb"):
            continue

        path = os.path.join(root, fn)

        try:
            nb = nbformat.read(path, as_version=4)
        except Exception as e:
            print(f"Unreadable Notebook (skip): {path} | {e}")
            continue

        changes_in_file = 0
        for cell in nb.cells:
            if cell.get("cell_type") in ("code", "markdown"):
                new_source, n = pattern.subn(replacement, cell.get("source", ""))
                if n:
                    cell["source"] = new_source
                    changes_in_file += n

        if changes_in_file:
            nbformat.write(nb, path)
            print(f"Modified: {path} | Changes: {changes_in_file}")
            files_modified += 1
            total_changes += changes_in_file

print("\nSummary")
print(f"Files modified: {files_modified}")
print(f"Total replacements: {total_changes}")
# Out:
# Modified: Test on prime editing/HEK293T_PE2/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2/Few-shot prediction/Few-shot expert prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2/Few-shot prediction/.ipynb_checkpoints/Few-shot expert prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HCT116_PE2/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HCT116_PE2/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HeLa_PE2max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HeLa_PE2max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/A549_PE2max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/A549_PE2max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/MDA_MB_231_PE2/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/MDA_MB_231_PE2/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2max/Few-shot prediction/Few-shot expert prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE2max/Few-shot prediction/.ipynb_checkpoints/Few-shot expert prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/DLD1_PE4max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/DLD1_PE4max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/A549_PE4max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/A549_PE4max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE4max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE4max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE4max/Few-shot prediction/Few-shot expert prediction.ipynb | Changes: 1
# Modified: Test on prime editing/HEK293T_PE4max/Few-shot prediction/.ipynb_checkpoints/Few-shot expert prediction-checkpoint.ipynb | Changes: 1
# Modified: Test on prime editing/DLD1_PE2max/Zero-shot prediction/Zero-shot generalist prediction.ipynb | Changes: 1
# Modified: Test on prime editing/DLD1_PE2max/Zero-shot prediction/.ipynb_checkpoints/Zero-shot generalist prediction-checkpoint.ipynb | Changes: 1
#
# Summary
# Files modified: 26
# Total replacements: 26
