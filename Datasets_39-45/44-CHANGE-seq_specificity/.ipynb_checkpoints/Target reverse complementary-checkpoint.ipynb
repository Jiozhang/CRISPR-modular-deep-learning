# %%
def reverse_complement(seq):
    complement = {
        'A': 'T', 'T': 'A',
        'C': 'G', 'G': 'C',
        'U': 'A',  # Optional: supports RNA input
        'N': 'N',
        'a': 't', 't': 'a',
        'c': 'g', 'g': 'c',
        'u': 'a',
        'n': 'n'
    }

    return ''.join(complement.get(base, base) for base in reversed(seq))


def reverse_complement_file(input_file, output_file):
    with open(input_file, "r") as infile, open(output_file, "w") as outfile:
        for line in infile:
            seq = line.strip()
            if seq:
                rc_seq = reverse_complement(seq[0:20])
                outfile.write(rc_seq + "\n")
            else:
                outfile.write("\n")  # Preserve empty lines


# Example usage
input_file = "target_seqs.txt"
output_file = "target_seqs_rc.txt"

reverse_complement_file(input_file, output_file)

print('finished')
